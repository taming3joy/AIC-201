# %%
#import all the neccesary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("SR386_labels.csv")

# %%
df.sample(20)
# Out:
#      case_id  died_within_5_years days_till_death  crc_primary_cause_of_death  \
# 249      353                  0.0           Alive                         NaN
# 389      534                  0.0           Alive                         NaN
# 127      184                  0.0           Alive                         NaN
# 176      255                  0.0           Alive                         NaN
# 121      177                  0.0           Alive                         NaN
# 111      164                  1.0              56                         1.0
# 346      480                  1.0            1567                         1.0
# 196      281                  0.0           Alive                         NaN
# 103      148                  0.0           Alive                         NaN
# 354      489                  0.0           Alive                         NaN
# 377      519                  0.0           Alive                         NaN
# 16        27                  1.0             872                         1.0
# 98       140                  0.0           Alive                         NaN
# 359      494                  1.0            1461                         1.0
# 382      524                  0.0           Alive                         NaN
# 267      381                  1.0            2297                         NaN
# 130      189                  0.0           Alive                         NaN
# 404      554                  0.0           Alive                         NaN
# 39        57                  0.0           Alive                         NaN
# 97       138                  0.0           Alive                         NaN
#
#      age_at_diagnosis sex   site_of_tumour site_of_tumour_grouping kras_ex_2  \
# 249                69   M     rectosigmoid                  rectum        WT
# 389                76   M    sigmoid colon           sigmoid colon        WT
# 127                61   F           rectum                  rectum  M (G12V)
# 176                71   M    sigmoid colon           sigmoid colon  M (G12C)
# 121                46   M           rectum                  rectum        WT
# 111                58   M  ascending colon         ascending colon        WT
# 346                57   F           caecum                  caecum        WT
# 196                60   M     rectosigmoid                  rectum        WT
# 103                63   M  splenic flexure         splenic flexure  M (G12D)
# 354                76   M     upper rectum                  rectum        WT
# 377                77   M           rectum                  rectum        WT
# 16                 65   F           caecum                  caecum  M (G12V)
# 98                 61   M    sigmoid colon           sigmoid colon  M (G12C)
# 359                64   F           rectum                  rectum        WT
# 382                48   F           rectum                  rectum        WT
# 267                85   M           rectum                  rectum        WT
# 130                48   F     lower rectum                  rectum        WT
# 404                70   M           rectum                  rectum        WT
# 39                 57   M    sigmoid colon           sigmoid colon        WT
# 97                 76   F     rectosigmoid                  rectum  M (G12V)
#
#     kras_ex_3  ...    pN   pM             tumour_type     differentiation  \
# 249        WT  ...    N0  NaN                     A/C                 Mod
# 389        WT  ...    N0  NaN                     A/C                 Mod
# 127        WT  ...    N0  NaN                     A/C                 Mod
# 176        WT  ...    N0  NaN                     A/C                 Mod
# 121        WT  ...    N1  NaN                     A/C                 Mod
# 111        WT  ...   pN2  NaN                     A/C                 Mod
# 346        WT  ...    N0  NaN                     A/C                Well
# 196        WT  ...  ypN1  NaN                     A/C                 Mod
# 103        WT  ...    N2  NaN                     A/C                 Mod
# 354        WT  ...    N1  NaN                     A/C                 Mod
# 377        WT  ...    N0  NaN                     A/C                 Mod
# 16         WT  ...    N0  NaN          A/C (mucinous)  Well (focally mod)
# 98         WT  ...    N2  NaN                     A/C                 Mod
# 359        WT  ...    N0  NaN                     A/C                 Mod
# 382  M (Q61H)  ...    N2  NaN                     A/C         Mod to Poor
# 267        WT  ...    N0  NaN  A/C (focally mucinous)                 Mod
# 130        WT  ...  ypN2  NaN                     A/C  Mod (focally poor)
# 404        WT  ...  ypN2  NaN                     A/C                 Mod
# 39         WT  ...   pN1  NaN                     A/C                 Mod
# 97         WT  ...    N1  NaN                     A/C                 Mod
#
#     peri_surface_involved  distance_to_peritoneum_macroscopic_measurement  \
# 249                     N                                            >5mm
# 389                     N                                           2.5mm
# 127                     N                                            >5mm
# 176                     N                                             1mm
# 121                     N                                           0.2mm
# 111                     N                                             1mm
# 346                     Y                                             0mm
# 196                     N                                             4mm
# 103                     N                                             4mm
# 354                     N                                             1mm
# 377                     N                                               -
# 16                      Y                                             NaN
# 98                      N                                             1mm
# 359                     N                                  Not applicable
# 382                     Y                                             0mm
# 267                     N                                             1mm
# 130                     N                                    Not measured
# 404                     N                                    Not measured
# 39                      Y                                             0mm
# 97                      N                                           >10mm
#
#     em_lvi       em_lvi_notes pre-op_radio pre-op_chemo
# 249      N                NaN            -            -
# 389      N                NaN            -            -
# 127      N                NaN            N            N
# 176      N                NaN            -            -
# 121      Y             Venous            N            Y
# 111      Y                NaN            -            -
# 346      N                NaN            -            -
# 196      Y             Venous            -            -
# 103      N                NaN            -            -
# 354      Y                NaN            N            N
# 377      Y             Venous            N            Y
# 16       N                NaN            -            -
# 98       N  Intramural venous            -            -
# 359      Y  Extramural venous            -            -
# 382      Y             Venous            N            N
# 267      Y             Venous            N            N
# 130      Y             Venous            N            Y
# 404      N                NaN            Y            N
# 39       Y             Venous            -            -
# 97       N                NaN            -            N
#
# [20 rows x 30 columns]

# %%
#Initial EDA of data
df.info() #Show datatypes
df.describe(include='all').transpose()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 427 entries, 0 to 426
# Data columns (total 30 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   case_id                                         427 non-null    int64
#  1   died_within_5_years                             425 non-null    float64
#  2   days_till_death                                 425 non-null    object
#  3   crc_primary_cause_of_death                      95 non-null     float64
#  4   age_at_diagnosis                                427 non-null    int64
#  5   sex                                             427 non-null    object
#  6   site_of_tumour                                  425 non-null    object
#  7   site_of_tumour_grouping                         425 non-null    object
#  8   kras_ex_2                                       427 non-null    object
#  9   kras_ex_3                                       427 non-null    object
#  10  kras_codon_117                                  427 non-null    object
#  11  nras_ex_2                                       427 non-null    object
#  12  nras_ex_3                                       427 non-null    object
#  13  braf_mutant_status                              427 non-null    object
#  14  mmr_ihc                                         427 non-null    object
#  15  mmr_loss_binary                                 427 non-null    int64
#  16  primary_metastatic                              427 non-null    object
#  17  stage                                           426 non-null    object
#  18  stage_subgroup                                  426 non-null    object
#  19  pT                                              426 non-null    object
#  20  pN                                              426 non-null    object
#  21  pM                                              34 non-null     object
#  22  tumour_type                                     425 non-null    object
#  23  differentiation                                 425 non-null    object
#  24  peri_surface_involved                           421 non-null    object
#  25  distance_to_peritoneum_macroscopic_measurement  402 non-null    object
#  26  em_lvi                                          424 non-null    object
#  27  em_lvi_notes                                    205 non-null    object
#  28  pre-op_radio                                    425 non-null    object
#  29  pre-op_chemo                                    425 non-null    object
# dtypes: float64(2), int64(3), object(25)
# memory usage: 100.2+ KB
#                                                 count unique      top freq  \
# case_id                                         427.0    NaN      NaN  NaN
# died_within_5_years                             425.0    NaN      NaN  NaN
# days_till_death                                   425    157    Alive  264
# crc_primary_cause_of_death                       95.0    NaN      NaN  NaN
# age_at_diagnosis                                427.0    NaN      NaN  NaN
# sex                                               427      2        M  230
# site_of_tumour                                    425     32   rectum   98
# site_of_tumour_grouping                           425      8   rectum  166
# kras_ex_2                                         427      8       WT  291
# kras_ex_3                                         427      7       WT  415
# kras_codon_117                                    427      3       WT  403
# nras_ex_2                                         427      6       WT  417
# nras_ex_3                                         427      5       WT  408
# braf_mutant_status                                427      8       WT  379
# mmr_ihc                                           427      3  NO LOSS  395
# mmr_loss_binary                                 427.0    NaN      NaN  NaN
# primary_metastatic                                427      1        P  427
# stage                                             426      5        2  153
# stage_subgroup                                    426      7       2A  120
# pT                                                426     11      pT3  210
# pN                                                426     11       N0  216
# pM                                                 34      6       M1   19
# tumour_type                                       425     17      A/C  369
# differentiation                                   425     29      Mod  324
# peri_surface_involved                             421      9        N  297
# distance_to_peritoneum_macroscopic_measurement    402     79      0mm   72
# em_lvi                                            424      6        N  228
# em_lvi_notes                                      205     41   Venous   93
# pre-op_radio                                      425      4        -  324
# pre-op_chemo                                      425      5        -  317
#
#                                                       mean         std   min  \
# case_id                                         299.953162  168.844478   1.0
# died_within_5_years                               0.378824    0.485666   0.0
# days_till_death                                        NaN         NaN   NaN
# crc_primary_cause_of_death                             1.0         0.0   1.0
# age_at_diagnosis                                 67.885246   12.000526  33.0
# sex                                                    NaN         NaN   NaN
# site_of_tumour                                         NaN         NaN   NaN
# site_of_tumour_grouping                                NaN         NaN   NaN
# kras_ex_2                                              NaN         NaN   NaN
# kras_ex_3                                              NaN         NaN   NaN
# kras_codon_117                                         NaN         NaN   NaN
# nras_ex_2                                              NaN         NaN   NaN
# nras_ex_3                                              NaN         NaN   NaN
# braf_mutant_status                                     NaN         NaN   NaN
# mmr_ihc                                                NaN         NaN   NaN
# mmr_loss_binary                                   0.074941    0.263606   0.0
# primary_metastatic                                     NaN         NaN   NaN
# stage                                                  NaN         NaN   NaN
# stage_subgroup                                         NaN         NaN   NaN
# pT                                                     NaN         NaN   NaN
# pN                                                     NaN         NaN   NaN
# pM                                                     NaN         NaN   NaN
# tumour_type                                            NaN         NaN   NaN
# differentiation                                        NaN         NaN   NaN
# peri_surface_involved                                  NaN         NaN   NaN
# distance_to_peritoneum_macroscopic_measurement         NaN         NaN   NaN
# em_lvi                                                 NaN         NaN   NaN
# em_lvi_notes                                           NaN         NaN   NaN
# pre-op_radio                                           NaN         NaN   NaN
# pre-op_chemo                                           NaN         NaN   NaN
#
#                                                   25%    50%    75%    max
# case_id                                         153.0  303.0  447.5  583.0
# died_within_5_years                               0.0    0.0    1.0    1.0
# days_till_death                                   NaN    NaN    NaN    NaN
# crc_primary_cause_of_death                        1.0    1.0    1.0    1.0
# age_at_diagnosis                                 59.0   69.0   77.0   97.0
# sex                                               NaN    NaN    NaN    NaN
# site_of_tumour                                    NaN    NaN    NaN    NaN
# site_of_tumour_grouping                           NaN    NaN    NaN    NaN
# kras_ex_2                                         NaN    NaN    NaN    NaN
# kras_ex_3                                         NaN    NaN    NaN    NaN
# kras_codon_117                                    NaN    NaN    NaN    NaN
# nras_ex_2                                         NaN    NaN    NaN    NaN
# nras_ex_3                                         NaN    NaN    NaN    NaN
# braf_mutant_status                                NaN    NaN    NaN    NaN
# mmr_ihc                                           NaN    NaN    NaN    NaN
# mmr_loss_binary                                   0.0    0.0    0.0    1.0
# primary_metastatic                                NaN    NaN    NaN    NaN
# stage                                             NaN    NaN    NaN    NaN
# stage_subgroup                                    NaN    NaN    NaN    NaN
# pT                                                NaN    NaN    NaN    NaN
# pN                                                NaN    NaN    NaN    NaN
# pM                                                NaN    NaN    NaN    NaN
# tumour_type                                       NaN    NaN    NaN    NaN
# differentiation                                   NaN    NaN    NaN    NaN
# peri_surface_involved                             NaN    NaN    NaN    NaN
# distance_to_peritoneum_macroscopic_measurement    NaN    NaN    NaN    NaN
# em_lvi                                            NaN    NaN    NaN    NaN
# em_lvi_notes                                      NaN    NaN    NaN    NaN
# pre-op_radio                                      NaN    NaN    NaN    NaN
# pre-op_chemo                                      NaN    NaN    NaN    NaN

# %%
df.isna().sum()
# Out:
# case_id                                             0
# died_within_5_years                                 2
# days_till_death                                     2
# crc_primary_cause_of_death                        332
# age_at_diagnosis                                    0
# sex                                                 0
# site_of_tumour                                      2
# site_of_tumour_grouping                             2
# kras_ex_2                                           0
# kras_ex_3                                           0
# kras_codon_117                                      0
# nras_ex_2                                           0
# nras_ex_3                                           0
# braf_mutant_status                                  0
# mmr_ihc                                             0
# mmr_loss_binary                                     0
# primary_metastatic                                  0
# stage                                               1
# stage_subgroup                                      1
# pT                                                  1
# pN                                                  1
# pM                                                393
# tumour_type                                         2
# differentiation                                     2
# peri_surface_involved                               6
# distance_to_peritoneum_macroscopic_measurement     25
# em_lvi                                              3
# em_lvi_notes                                      222
# pre-op_radio                                        2
# pre-op_chemo                                        2
# dtype: int64

# %%
#EDA of the attributes
for attribute in df.columns: #After age_at_diagnosis attribute
    print("Missing values: ",df[attribute].isna().sum())
    #Show unique value counts
    print("Unique values count:",df[attribute].nunique())
    print(df[attribute].value_counts())
    print()
# Out:
# Missing values:  0
# Unique values count: 427
# case_id
# 1      1
# 3      1
# 4      1
# 6      1
# 7      1
#       ..
# 578    1
# 580    1
# 581    1
# 582    1
# 583    1
# Name: count, Length: 427, dtype: int64
#
# Missing values:  2
# Unique values count: 2
# died_within_5_years
# 0.0    264
# 1.0    161
# Name: count, dtype: int64
#
# Missing values:  2
# Unique values count: 157
# days_till_death
# Alive    264
# 1188       2
# 350        2
# 643        2
# 331        2
#         ...
# 442        1
# 159        1
# 1148       1
# 1693       1
# 1296       1
# Name: count, Length: 157, dtype: int64
#
# Missing values:  332
# Unique values count: 1
# crc_primary_cause_of_death
# 1.0    95
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 56
# age_at_diagnosis
# 75    21
# 76    17
# 71    17
# 59    17
# 61    16
# 69    15
# 66    15
# 74    14
# 83    13
# 58    13
# 80    13
# 63    12
# 78    11
# 67    11
# 82    10
# 79    10
# 55    10
# 77    10
# 60    10
# 81    10
# 70    10
# 65     9
# 68     9
# 64     8
# 52     8
# 57     8
# 72     8
# 62     7
# 49     7
# 73     7
# 50     7
# 85     7
# 86     7
# 53     6
# 54     6
# 87     5
# 39     5
# 56     4
# 84     4
# 43     3
# 88     3
# 51     3
# 48     3
# 91     2
# 92     2
# 42     2
# 33     2
# 46     2
# 89     1
# 47     1
# 97     1
# 44     1
# 40     1
# 38     1
# 95     1
# 37     1
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 2
# sex
# M    230
# F    197
# Name: count, dtype: int64
#
# Missing values:  2
# Unique values count: 32
# site_of_tumour
# rectum                           98
# sigmoid colon                    71
# caecum                           54
# ascending colon                  41
# rectosigmoid                     40
# transverse colon                 22
# upper rectum                     15
# splenic flexure                  14
# lower rectum                     12
# descending colon                 11
# distal sigmoid colon              8
# sigmoid                           7
# hepatic flexure                   7
# caecum/ascending colon            6
# distal sigmoid                    2
# left colon                        1
# proximal descending colon         1
# descending/sigmoid junction??     1
# ascending/transverse colon        1
# proximal ascending colon          1
# lower caecum                      1
# distal descending colon           1
# upper rectum/sigmoid              1
# caecum/ileocaecal valve           1
# caecum/small bowel                1
# proximal transverse colon         1
# right hemicolon                   1
# ileocolic resection??             1
# rectosigmoid junction             1
# appendix                          1
# mid transverse colon              1
# lower descending colon            1
# Name: count, dtype: int64
#
# Missing values:  2
# Unique values count: 8
# site_of_tumour_grouping
# rectum              166
# sigmoid colon        89
# caecum               65
# ascending colon      43
# transverse colon     25
# descending colon     16
# splenic flexure      14
# hepatic flexure       7
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 8
# kras_ex_2
# WT          291
# M (G12D)     53
# M (G12V)     29
# M (G13D)     18
# M (G12C)     17
# M (G12S)     12
# M (G12A)      6
# FAIL          1
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 7
# kras_ex_3
# WT          415
# M (Q61L)      4
# M (Q61H)      3
# M (Q61R)      2
# M (G60V)      1
# M (Q61K)      1
# FAIL          1
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 3
# kras_codon_117
# WT           403
# FAIL          23
# M (K117N)      1
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 6
# nras_ex_2
# WT              417
# M (G12D)          5
# M (G12A)          2
# FAIL              1
# M (G12V)          1
# M (codon 14)      1
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 5
# nras_ex_3
# WT          408
# FAIL         12
# M (Q61L)      3
# M (Q61K)      2
# M (Q61R)      2
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 8
# braf_mutant_status
# WT                        379
# M (V600E)                  38
# M (V600E) - LOW LEVEL       5
# M (V600E)                   1
# FAIL                        1
# M (D584N) - LOW LEVEL       1
# M (S605G) - LOW LEVEL       1
# M (R603Q) - LOW LEVEL)      1
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 3
# mmr_ihc
# NO LOSS            395
# MLH1, PMS2 LOSS     28
# PMS2 LOSS            4
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 2
# mmr_loss_binary
# 0    395
# 1     32
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 1
# primary_metastatic
# P    427
# Name: count, dtype: int64
#
# Missing values:  1
# Unique values count: 5
# stage
# 2     153
# 3     120
# 3C     73
# 1      60
# 4      20
# Name: count, dtype: int64
#
# Missing values:  1
# Unique values count: 7
# stage_subgroup
# 2A    120
# 3B     96
# 3C     73
# 1      60
# 2B     33
# 3A     24
# 4      20
# Name: count, dtype: int64
#
# Missing values:  1
# Unique values count: 11
# pT
# pT3     210
# pT2      71
# pT4b     69
# pT4      30
# ypT3     18
# pT1      12
# pT4a     10
# ypT2      3
# ypT1      1
# Pt3       1
# pT        1
# Name: count, dtype: int64
#
# Missing values:  1
# Unique values count: 11
# pN
# N0      216
# N1      118
# N2       72
# ypN2      4
# pN1       4
# pN0       4
# pN2       4
# NX        1
# ypN0      1
# Nx        1
# ypN1      1
# Name: count, dtype: int64
#
# Missing values:  393
# Unique values count: 6
# pM
# M1             19
# MX              8
# Mx              4
# cM1             1
# cM1?            1
# cM1 (liver)     1
# Name: count, dtype: int64
#
# Missing values:  2
# Unique values count: 17
# tumour_type
# A/C                                                369
# A/C (mucinous)                                      18
# A/C (Mucinous)                                      13
# A/C (focally mucinous)                               7
# A/C (mucinous component)                             6
# A/C (mucinous with signet ring differentiation)      1
# Multifocal A/C                                       1
# A/C (mucinous and signet ring component)             1
# A/C (medullary like features)                        1
# A/C (villous adenoma like)                           1
# A/C (prominent mucinous differentitation)            1
# A/C (medullary features)                             1
# A/C (mucinous, predominantly signet ring)            1
# A/C (Medullary)                                      1
# A/C (residual)                                       1
# A/C (serrated morph and mucinous component)          1
# A/C (focally mucinous in <10%)                       1
# Name: count, dtype: int64
#
# Missing values:  2
# Unique values count: 29
# differentiation
# Mod                                                                     324
# Poor                                                                     44
# Well                                                                     19
# Mod (focally poor)                                                        6
# Mod to Poor                                                               4
# Mod (foci of poor at invasive front)                                      2
# Mod (predominantly)                                                       2
# Mod-Poor                                                                  2
# Mod (some areas of poor)                                                  2
# Poor (some mod regions with medullary features)                           1
# Well to Mod (mucinous component)                                          1
# Poor (areas of moderate)                                                  1
# Well (focally mod)                                                        1
# Mod (areas of poor)                                                       1
# Mod (leading edge poor with tumour budding)                               1
# Mod (some foci of poor)                                                   1
# Mod (small focus of mucinous differentiation and small foci of poor)      1
# Mod (focal poor at invasive front)                                        1
# Mod (foci of poor)                                                        1
# Mod (areas of mucinous, areas of poor)                                    1
# Mod (small areas of poorly differentiated)                                1
# Mod (mucinous areas and occasional signet)                                1
# Poor (focal signet ring cell morph)                                       1
# Mod (some mucinous differentiation)                                       1
# Mod (areas of poor differentiation, focal mucinous differentiation)       1
# Mod (areas of focal poor)                                                 1
# Mod to Poor (sig areas of poor)                                           1
# Mod (papillary architecture and mucinous differentiation)                 1
# Focally poor but overall mod                                              1
# Name: count, dtype: int64
#
# Missing values:  6
# Unique values count: 9
# peri_surface_involved
# N                                           297
# Y                                            94
# Not identified                               13
# -                                            10
# ??                                            3
# N (N/A)                                       1
# Absent                                        1
# Not directly visualised but presumed yes      1
# N?                                            1
# Name: count, dtype: int64
#
# Missing values:  25
# Unique values count: 79
# distance_to_peritoneum_macroscopic_measurement
# 0mm                       72
# -                         42
# 0.2mm                     15
# 0.3mm                     14
# <1mm                      14
#                           ..
# Clear but not measured     1
# 20mm                       1
# <0.2mm                     1
# About 5mm                  1
# 4.5mm                      1
# Name: count, Length: 79, dtype: int64
#
# Missing values:  3
# Unique values count: 6
# em_lvi
# N                 228
# Y                 173
# Not identified     18
# Probable            2
# -                   2
# Not present         1
# Name: count, dtype: int64
#
# Missing values:  222
# Unique values count: 41
# em_lvi_notes
# Venous                                                             93
# Intramural venous                                                  32
# Lymphatic and venous                                               17
# Venous and lymphatic                                                5
# Lymphatic and intramural venous                                     4
# Extra and intramural venous                                         4
# Venous and Lymphatic                                                3
# Extramural lymphatic and intramural venous                          3
# Lymphatic                                                           3
# Intramural venous invasion present                                  3
# Lymphatic and Venous                                                3
# Intra and extramural venous                                         2
# Perineural infiltration                                             2
# venous                                                              2
# Extramural venous                                                   2
# focal perineural infiltration also seen                             2
# Suspicious foci of lynphatic invasion                               1
# Venous                                                              1
# focal perineural infiltration present                               1
# venous invasion                                                     1
# Intra or extramural venous                                          1
# Lymphatic, single focus extramural                                  1
# Vascular                                                            1
# Suspicious of intramural venous                                     1
# Venous and lymphatic invasion                                       1
# Intramural venous                                                   1
# Focal lymphocapillary space invasion noted.                         1
# Venous focal perineural infiltration also                           1
# Lyphatic                                                            1
# focus of smucosal lymphocapillary space invasion present            1
# Lymphatic not venous                                                1
# Extramural venous and lymphatic                                     1
# Intramural venous, extramural lymphatic                             1
# Venous and intramural lymphatic                                     1
# Submucosal lymphatic invasion                                       1
# Lymphatic and venous, extensive perineural infiltration alos        1
# extra venous, perineural invasion also                              1
# Extramural venous and supiscious focus of extramural lymphatic      1
# S mucosal vascular invasion but no extramural vascular invasion     1
# Lymphatic and venous and intramural venous                          1
# Intramural present, extramural not identified                       1
# Name: count, dtype: int64
#
# Missing values:  2
# Unique values count: 4
# pre-op_radio
# -               324
# N                67
# Y                33
# Not specifed      1
# Name: count, dtype: int64
#
# Missing values:  2
# Unique values count: 5
# pre-op_chemo
# -                                     317
# N                                      89
# Y                                      15
# Not specifed                            3
# Post DXT (docetaxel) (long course)      1
# Name: count, dtype: int64

# %%
df=df.drop(labels=["case_id","days_till_death"],axis=1) #Drop case id since not needed
#"days_till_death" cannot be used, since if "days_till_death" = Alive -> died_within_5_years = 0, and 1 otherwise
df=df.drop(labels=["crc_primary_cause_of_death","pM","em_lvi_notes"],axis=1) #Too many missing values

# %%
df = df[df["died_within_5_years"].isna() == False] #Remove all empty records of "died_within_5_years"
df["died_within_5_years"]=df["died_within_5_years"].astype(int) #Convert to int64 datatype
df["died_within_5_years"].value_counts()
# Out:
# died_within_5_years
# 0    264
# 1    161
# Name: count, dtype: int64

# %%
#Cleaning the sex attribute
print("Missing values: ",df['sex'].isna().sum())
print(df['sex'].value_counts())
#Data preprocessing to convert sex to binary: M = 1 & F = 0
df['sex'] = df['sex'].map({'M': False, 'F': True,})
df.rename(columns={'sex': 'male'}, inplace=True)
df['male'] = df['male'].astype(bool)
df['male'].value_counts()
# Out:
# Missing values:  0
# sex
# M    229
# F    196
# Name: count, dtype: int64
# male
# False    229
# True     196
# Name: count, dtype: int64

# %%
#Cleaning the site_of_tumour attribute
print("Missing values: ",df['site_of_tumour'].isna().sum())
#Fill in the missing values with the attribute mode (Categorical values)
df['site_of_tumour']=df['site_of_tumour'].fillna(df['site_of_tumour'].mode()[0])

#Show unique value counts
print("Unique values count:",df['site_of_tumour'].nunique())
print(df['site_of_tumour'].value_counts())

#Replace unique value where counts <=2 with "others"
counts = df['site_of_tumour'].value_counts()
unique = list(counts[counts<=2].index)
df['site_of_tumour']=df['site_of_tumour'].replace(unique,"others")
# Out:
# Missing values:  2
# Unique values count: 32
# site_of_tumour
# rectum                           99
# sigmoid colon                    71
# caecum                           54
# ascending colon                  41
# rectosigmoid                     40
# transverse colon                 22
# upper rectum                     15
# splenic flexure                  14
# lower rectum                     12
# descending colon                 10
# distal sigmoid colon              8
# sigmoid                           7
# hepatic flexure                   7
# caecum/ascending colon            6
# distal sigmoid                    2
# left colon                        1
# proximal descending colon         1
# descending/sigmoid junction??     1
# ascending/transverse colon        1
# proximal ascending colon          1
# lower caecum                      1
# distal descending colon           1
# upper rectum/sigmoid              1
# caecum/ileocaecal valve           1
# caecum/small bowel                1
# proximal transverse colon         1
# right hemicolon                   1
# ileocolic resection??             1
# rectosigmoid junction             1
# appendix                          1
# mid transverse colon              1
# lower descending colon            1
# Name: count, dtype: int64

# %%
#Cleaning the site_of_tumour_grouping attribute
print("Missing values: ",df['site_of_tumour_grouping'].isna().sum())
#Fill in the missing values with the attribute mode (Categorical values)
df['site_of_tumour_grouping']=df['site_of_tumour_grouping'].fillna(df['site_of_tumour_grouping'].mode()[0])

#Show unique value counts
print("Unique values count:",df['site_of_tumour_grouping'].nunique())
print(df['site_of_tumour_grouping'].value_counts())
# Out:
# Missing values:  2
# Unique values count: 8
# site_of_tumour_grouping
# rectum              167
# sigmoid colon        89
# caecum               65
# ascending colon      43
# transverse colon     25
# descending colon     15
# splenic flexure      14
# hepatic flexure       7
# Name: count, dtype: int64

# %%
# #Perform one-hot encoding on catergorical attributes
# df = pd.get_dummies(df,columns=['site_of_tumour'],drop_first=True)
