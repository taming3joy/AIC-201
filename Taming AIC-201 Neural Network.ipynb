# %%
#import all the neccesary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("SR386_labels.csv")

# %%
df.sample(20)
# Out:
#      died_within_5_years  age_at_diagnosis  male  kras_ex_2  kras_ex_3  \
# 133                    0          0.453125     0          0          0
# 205                    0          0.656250     0          1          0
# 425                    1          0.390625     1          0          0
# 244                    0          0.593750     0          1          0
# 41                     0          0.656250     1          1          0
# 412                    0          0.484375     1          0          0
# 341                    1          0.093750     0          0          0
# 152                    0          0.265625     1          0          0
# 391                    0          0.250000     0          0          0
# 146                    1          0.437500     1          1          0
# 263                    0          0.500000     0          0          0
# 236                    1          0.328125     1          1          0
# 315                    0          0.406250     0          1          0
# 342                    0          0.390625     0          0          0
# 262                    0          0.593750     1          0          0
# 157                    0          0.453125     0          0          0
# 245                    1          0.640625     0          0          0
# 231                    0          0.515625     1          0          0
# 265                    0          0.562500     1          0          0
# 199                    0          0.562500     1          1          0
#
#      kras_codon_117  nras_ex_2  braf_mutant_status  mmr_loss_binary  stage  \
# 133               0          0                   0                0   0.50
# 205               1          0                   0                0   0.25
# 425               0          0                   0                0   0.00
# 244               0          0                   0                0   0.75
# 41                0          0                   0                0   0.00
# 412               0          0                   0                0   0.50
# 341               1          0                   1                0   1.00
# 152               0          0                   0                0   0.50
# 391               0          0                   0                0   0.50
# 146               0          0                   0                0   0.75
# 263               0          0                   0                1   0.00
# 236               0          0                   0                0   0.75
# 315               0          0                   0                0   0.50
# 342               0          0                   0                0   0.00
# 262               0          0                   0                0   0.25
# 157               0          0                   0                0   0.25
# 245               0          0                   0                0   0.50
# 231               0          0                   1                0   1.00
# 265               0          0                   0                0   0.50
# 199               0          1                   0                0   0.25
#
#      ...  pT_pT1  pT_pT2  pT_pT3  pT_pT4  pT_pT4a  pT_pT4b  pT_ypT3  pN_N1  \
# 133  ...       0       0       1       0        0        0        0      1
# 205  ...       0       0       1       0        0        0        0      0
# 425  ...       0       1       0       0        0        0        0      0
# 244  ...       0       0       1       0        0        0        0      0
# 41   ...       0       0       0       0        0        0        0      0
# 412  ...       0       0       1       0        0        0        0      1
# 341  ...       0       0       0       0        0        1        0      0
# 152  ...       0       1       0       0        0        0        0      1
# 391  ...       0       0       1       0        0        0        0      1
# 146  ...       0       0       0       0        0        1        0      0
# 263  ...       1       0       0       0        0        0        0      0
# 236  ...       0       0       0       0        0        1        0      0
# 315  ...       0       0       1       0        0        0        0      1
# 342  ...       1       0       0       0        0        0        0      0
# 262  ...       0       0       1       0        0        0        0      0
# 157  ...       0       0       0       0        0        0        1      0
# 245  ...       0       0       1       0        0        0        0      1
# 231  ...       0       0       1       0        0        0        0      0
# 265  ...       0       0       1       0        0        0        0      1
# 199  ...       0       0       1       0        0        0        0      0
#
#      pN_N2  pN_others
# 133      0          0
# 205      0          0
# 425      0          0
# 244      1          0
# 41       0          0
# 412      0          0
# 341      1          0
# 152      0          0
# 391      0          0
# 146      1          0
# 263      0          0
# 236      1          0
# 315      0          0
# 342      0          0
# 262      0          0
# 157      0          0
# 245      0          0
# 231      0          0
# 265      0          0
# 199      0          0
#
# [20 rows x 49 columns]

# %%
#Initial EDA of data
df.info() #Show datatypes
df.describe(include='all').transpose()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 427 entries, 0 to 426
# Data columns (total 30 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   case_id                                         427 non-null    int64
#  1   died_within_5_years                             425 non-null    float64
#  2   days_till_death                                 425 non-null    object
#  3   crc_primary_cause_of_death                      95 non-null     float64
#  4   age_at_diagnosis                                427 non-null    int64
#  5   sex                                             427 non-null    object
#  6   site_of_tumour                                  425 non-null    object
#  7   site_of_tumour_grouping                         425 non-null    object
#  8   kras_ex_2                                       427 non-null    object
#  9   kras_ex_3                                       427 non-null    object
#  10  kras_codon_117                                  427 non-null    object
#  11  nras_ex_2                                       427 non-null    object
#  12  nras_ex_3                                       427 non-null    object
#  13  braf_mutant_status                              427 non-null    object
#  14  mmr_ihc                                         427 non-null    object
#  15  mmr_loss_binary                                 427 non-null    int64
#  16  primary_metastatic                              427 non-null    object
#  17  stage                                           426 non-null    object
#  18  stage_subgroup                                  426 non-null    object
#  19  pT                                              426 non-null    object
#  20  pN                                              426 non-null    object
#  21  pM                                              34 non-null     object
#  22  tumour_type                                     425 non-null    object
#  23  differentiation                                 425 non-null    object
#  24  peri_surface_involved                           421 non-null    object
#  25  distance_to_peritoneum_macroscopic_measurement  402 non-null    object
#  26  em_lvi                                          424 non-null    object
#  27  em_lvi_notes                                    205 non-null    object
#  28  pre-op_radio                                    425 non-null    object
#  29  pre-op_chemo                                    425 non-null    object
# dtypes: float64(2), int64(3), object(25)
# memory usage: 100.2+ KB
#                                                 count unique      top freq  \
# case_id                                         427.0    NaN      NaN  NaN
# died_within_5_years                             425.0    NaN      NaN  NaN
# days_till_death                                   425    157    Alive  264
# crc_primary_cause_of_death                       95.0    NaN      NaN  NaN
# age_at_diagnosis                                427.0    NaN      NaN  NaN
# sex                                               427      2        M  230
# site_of_tumour                                    425     32   rectum   98
# site_of_tumour_grouping                           425      8   rectum  166
# kras_ex_2                                         427      8       WT  291
# kras_ex_3                                         427      7       WT  415
# kras_codon_117                                    427      3       WT  403
# nras_ex_2                                         427      6       WT  417
# nras_ex_3                                         427      5       WT  408
# braf_mutant_status                                427      8       WT  379
# mmr_ihc                                           427      3  NO LOSS  395
# mmr_loss_binary                                 427.0    NaN      NaN  NaN
# primary_metastatic                                427      1        P  427
# stage                                             426      5        2  153
# stage_subgroup                                    426      7       2A  120
# pT                                                426     11      pT3  210
# pN                                                426     11       N0  216
# pM                                                 34      6       M1   19
# tumour_type                                       425     17      A/C  369
# differentiation                                   425     29      Mod  324
# peri_surface_involved                             421      9        N  297
# distance_to_peritoneum_macroscopic_measurement    402     79      0mm   72
# em_lvi                                            424      6        N  228
# em_lvi_notes                                      205     41   Venous   93
# pre-op_radio                                      425      4        -  324
# pre-op_chemo                                      425      5        -  317
#
#                                                       mean         std   min  \
# case_id                                         299.953162  168.844478   1.0
# died_within_5_years                               0.378824    0.485666   0.0
# days_till_death                                        NaN         NaN   NaN
# crc_primary_cause_of_death                             1.0         0.0   1.0
# age_at_diagnosis                                 67.885246   12.000526  33.0
# sex                                                    NaN         NaN   NaN
# site_of_tumour                                         NaN         NaN   NaN
# site_of_tumour_grouping                                NaN         NaN   NaN
# kras_ex_2                                              NaN         NaN   NaN
# kras_ex_3                                              NaN         NaN   NaN
# kras_codon_117                                         NaN         NaN   NaN
# nras_ex_2                                              NaN         NaN   NaN
# nras_ex_3                                              NaN         NaN   NaN
# braf_mutant_status                                     NaN         NaN   NaN
# mmr_ihc                                                NaN         NaN   NaN
# mmr_loss_binary                                   0.074941    0.263606   0.0
# primary_metastatic                                     NaN         NaN   NaN
# stage                                                  NaN         NaN   NaN
# stage_subgroup                                         NaN         NaN   NaN
# pT                                                     NaN         NaN   NaN
# pN                                                     NaN         NaN   NaN
# pM                                                     NaN         NaN   NaN
# tumour_type                                            NaN         NaN   NaN
# differentiation                                        NaN         NaN   NaN
# peri_surface_involved                                  NaN         NaN   NaN
# distance_to_peritoneum_macroscopic_measurement         NaN         NaN   NaN
# em_lvi                                                 NaN         NaN   NaN
# em_lvi_notes                                           NaN         NaN   NaN
# pre-op_radio                                           NaN         NaN   NaN
# pre-op_chemo                                           NaN         NaN   NaN
#
#                                                   25%    50%    75%    max
# case_id                                         153.0  303.0  447.5  583.0
# died_within_5_years                               0.0    0.0    1.0    1.0
# days_till_death                                   NaN    NaN    NaN    NaN
# crc_primary_cause_of_death                        1.0    1.0    1.0    1.0
# age_at_diagnosis                                 59.0   69.0   77.0   97.0
# sex                                               NaN    NaN    NaN    NaN
# site_of_tumour                                    NaN    NaN    NaN    NaN
# site_of_tumour_grouping                           NaN    NaN    NaN    NaN
# kras_ex_2                                         NaN    NaN    NaN    NaN
# kras_ex_3                                         NaN    NaN    NaN    NaN
# kras_codon_117                                    NaN    NaN    NaN    NaN
# nras_ex_2                                         NaN    NaN    NaN    NaN
# nras_ex_3                                         NaN    NaN    NaN    NaN
# braf_mutant_status                                NaN    NaN    NaN    NaN
# mmr_ihc                                           NaN    NaN    NaN    NaN
# mmr_loss_binary                                   0.0    0.0    0.0    1.0
# primary_metastatic                                NaN    NaN    NaN    NaN
# stage                                             NaN    NaN    NaN    NaN
# stage_subgroup                                    NaN    NaN    NaN    NaN
# pT                                                NaN    NaN    NaN    NaN
# pN                                                NaN    NaN    NaN    NaN
# pM                                                NaN    NaN    NaN    NaN
# tumour_type                                       NaN    NaN    NaN    NaN
# differentiation                                   NaN    NaN    NaN    NaN
# peri_surface_involved                             NaN    NaN    NaN    NaN
# distance_to_peritoneum_macroscopic_measurement    NaN    NaN    NaN    NaN
# em_lvi                                            NaN    NaN    NaN    NaN
# em_lvi_notes                                      NaN    NaN    NaN    NaN
# pre-op_radio                                      NaN    NaN    NaN    NaN
# pre-op_chemo                                      NaN    NaN    NaN    NaN

# %%
df.isna().sum()
# Out:
# case_id                                             0
# died_within_5_years                                 2
# days_till_death                                     2
# crc_primary_cause_of_death                        332
# age_at_diagnosis                                    0
# sex                                                 0
# site_of_tumour                                      2
# site_of_tumour_grouping                             2
# kras_ex_2                                           0
# kras_ex_3                                           0
# kras_codon_117                                      0
# nras_ex_2                                           0
# nras_ex_3                                           0
# braf_mutant_status                                  0
# mmr_ihc                                             0
# mmr_loss_binary                                     0
# primary_metastatic                                  0
# stage                                               1
# stage_subgroup                                      1
# pT                                                  1
# pN                                                  1
# pM                                                393
# tumour_type                                         2
# differentiation                                     2
# peri_surface_involved                               6
# distance_to_peritoneum_macroscopic_measurement     25
# em_lvi                                              3
# em_lvi_notes                                      222
# pre-op_radio                                        2
# pre-op_chemo                                        2
# dtype: int64

# %%
#EDA of the attributes
for attribute in df.columns: #After age_at_diagnosis attribute
    print("Missing values: ",df[attribute].isna().sum())
    #Show unique value counts
    print("Unique values count:",df[attribute].nunique())
    print(df[attribute].value_counts())
    print()
# Out:
# Missing values:  0
# Unique values count: 427
# case_id
# 1      1
# 3      1
# 4      1
# 6      1
# 7      1
#       ..
# 578    1
# 580    1
# 581    1
# 582    1
# 583    1
# Name: count, Length: 427, dtype: int64
#
# Missing values:  2
# Unique values count: 2
# died_within_5_years
# 0.0    264
# 1.0    161
# Name: count, dtype: int64
#
# Missing values:  2
# Unique values count: 157
# days_till_death
# Alive    264
# 1188       2
# 350        2
# 643        2
# 331        2
#         ...
# 442        1
# 159        1
# 1148       1
# 1693       1
# 1296       1
# Name: count, Length: 157, dtype: int64
#
# Missing values:  332
# Unique values count: 1
# crc_primary_cause_of_death
# 1.0    95
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 56
# age_at_diagnosis
# 75    21
# 76    17
# 71    17
# 59    17
# 61    16
# 69    15
# 66    15
# 74    14
# 83    13
# 58    13
# 80    13
# 63    12
# 78    11
# 67    11
# 82    10
# 79    10
# 55    10
# 77    10
# 60    10
# 81    10
# 70    10
# 65     9
# 68     9
# 64     8
# 52     8
# 57     8
# 72     8
# 62     7
# 49     7
# 73     7
# 50     7
# 85     7
# 86     7
# 53     6
# 54     6
# 87     5
# 39     5
# 56     4
# 84     4
# 43     3
# 88     3
# 51     3
# 48     3
# 91     2
# 92     2
# 42     2
# 33     2
# 46     2
# 89     1
# 47     1
# 97     1
# 44     1
# 40     1
# 38     1
# 95     1
# 37     1
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 2
# sex
# M    230
# F    197
# Name: count, dtype: int64
#
# Missing values:  2
# Unique values count: 32
# site_of_tumour
# rectum                           98
# sigmoid colon                    71
# caecum                           54
# ascending colon                  41
# rectosigmoid                     40
# transverse colon                 22
# upper rectum                     15
# splenic flexure                  14
# lower rectum                     12
# descending colon                 11
# distal sigmoid colon              8
# sigmoid                           7
# hepatic flexure                   7
# caecum/ascending colon            6
# distal sigmoid                    2
# left colon                        1
# proximal descending colon         1
# descending/sigmoid junction??     1
# ascending/transverse colon        1
# proximal ascending colon          1
# lower caecum                      1
# distal descending colon           1
# upper rectum/sigmoid              1
# caecum/ileocaecal valve           1
# caecum/small bowel                1
# proximal transverse colon         1
# right hemicolon                   1
# ileocolic resection??             1
# rectosigmoid junction             1
# appendix                          1
# mid transverse colon              1
# lower descending colon            1
# Name: count, dtype: int64
#
# Missing values:  2
# Unique values count: 8
# site_of_tumour_grouping
# rectum              166
# sigmoid colon        89
# caecum               65
# ascending colon      43
# transverse colon     25
# descending colon     16
# splenic flexure      14
# hepatic flexure       7
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 8
# kras_ex_2
# WT          291
# M (G12D)     53
# M (G12V)     29
# M (G13D)     18
# M (G12C)     17
# M (G12S)     12
# M (G12A)      6
# FAIL          1
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 7
# kras_ex_3
# WT          415
# M (Q61L)      4
# M (Q61H)      3
# M (Q61R)      2
# M (G60V)      1
# M (Q61K)      1
# FAIL          1
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 3
# kras_codon_117
# WT           403
# FAIL          23
# M (K117N)      1
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 6
# nras_ex_2
# WT              417
# M (G12D)          5
# M (G12A)          2
# FAIL              1
# M (G12V)          1
# M (codon 14)      1
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 5
# nras_ex_3
# WT          408
# FAIL         12
# M (Q61L)      3
# M (Q61K)      2
# M (Q61R)      2
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 8
# braf_mutant_status
# WT                        379
# M (V600E)                  38
# M (V600E) - LOW LEVEL       5
# M (V600E)                   1
# FAIL                        1
# M (D584N) - LOW LEVEL       1
# M (S605G) - LOW LEVEL       1
# M (R603Q) - LOW LEVEL)      1
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 3
# mmr_ihc
# NO LOSS            395
# MLH1, PMS2 LOSS     28
# PMS2 LOSS            4
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 2
# mmr_loss_binary
# 0    395
# 1     32
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 1
# primary_metastatic
# P    427
# Name: count, dtype: int64
#
# Missing values:  1
# Unique values count: 5
# stage
# 2     153
# 3     120
# 3C     73
# 1      60
# 4      20
# Name: count, dtype: int64
#
# Missing values:  1
# Unique values count: 7
# stage_subgroup
# 2A    120
# 3B     96
# 3C     73
# 1      60
# 2B     33
# 3A     24
# 4      20
# Name: count, dtype: int64
#
# Missing values:  1
# Unique values count: 11
# pT
# pT3     210
# pT2      71
# pT4b     69
# pT4      30
# ypT3     18
# pT1      12
# pT4a     10
# ypT2      3
# ypT1      1
# Pt3       1
# pT        1
# Name: count, dtype: int64
#
# Missing values:  1
# Unique values count: 11
# pN
# N0      216
# N1      118
# N2       72
# ypN2      4
# pN1       4
# pN0       4
# pN2       4
# NX        1
# ypN0      1
# Nx        1
# ypN1      1
# Name: count, dtype: int64
#
# Missing values:  393
# Unique values count: 6
# pM
# M1             19
# MX              8
# Mx              4
# cM1             1
# cM1?            1
# cM1 (liver)     1
# Name: count, dtype: int64
#
# Missing values:  2
# Unique values count: 17
# tumour_type
# A/C                                                369
# A/C (mucinous)                                      18
# A/C (Mucinous)                                      13
# A/C (focally mucinous)                               7
# A/C (mucinous component)                             6
# A/C (mucinous with signet ring differentiation)      1
# Multifocal A/C                                       1
# A/C (mucinous and signet ring component)             1
# A/C (medullary like features)                        1
# A/C (villous adenoma like)                           1
# A/C (prominent mucinous differentitation)            1
# A/C (medullary features)                             1
# A/C (mucinous, predominantly signet ring)            1
# A/C (Medullary)                                      1
# A/C (residual)                                       1
# A/C (serrated morph and mucinous component)          1
# A/C (focally mucinous in <10%)                       1
# Name: count, dtype: int64
#
# Missing values:  2
# Unique values count: 29
# differentiation
# Mod                                                                     324
# Poor                                                                     44
# Well                                                                     19
# Mod (focally poor)                                                        6
# Mod to Poor                                                               4
# Mod (foci of poor at invasive front)                                      2
# Mod (predominantly)                                                       2
# Mod-Poor                                                                  2
# Mod (some areas of poor)                                                  2
# Poor (some mod regions with medullary features)                           1
# Well to Mod (mucinous component)                                          1
# Poor (areas of moderate)                                                  1
# Well (focally mod)                                                        1
# Mod (areas of poor)                                                       1
# Mod (leading edge poor with tumour budding)                               1
# Mod (some foci of poor)                                                   1
# Mod (small focus of mucinous differentiation and small foci of poor)      1
# Mod (focal poor at invasive front)                                        1
# Mod (foci of poor)                                                        1
# Mod (areas of mucinous, areas of poor)                                    1
# Mod (small areas of poorly differentiated)                                1
# Mod (mucinous areas and occasional signet)                                1
# Poor (focal signet ring cell morph)                                       1
# Mod (some mucinous differentiation)                                       1
# Mod (areas of poor differentiation, focal mucinous differentiation)       1
# Mod (areas of focal poor)                                                 1
# Mod to Poor (sig areas of poor)                                           1
# Mod (papillary architecture and mucinous differentiation)                 1
# Focally poor but overall mod                                              1
# Name: count, dtype: int64
#
# Missing values:  6
# Unique values count: 9
# peri_surface_involved
# N                                           297
# Y                                            94
# Not identified                               13
# -                                            10
# ??                                            3
# N (N/A)                                       1
# Absent                                        1
# Not directly visualised but presumed yes      1
# N?                                            1
# Name: count, dtype: int64
#
# Missing values:  25
# Unique values count: 79
# distance_to_peritoneum_macroscopic_measurement
# 0mm                       72
# -                         42
# 0.2mm                     15
# 0.3mm                     14
# <1mm                      14
#                           ..
# Clear but not measured     1
# 20mm                       1
# <0.2mm                     1
# About 5mm                  1
# 4.5mm                      1
# Name: count, Length: 79, dtype: int64
#
# Missing values:  3
# Unique values count: 6
# em_lvi
# N                 228
# Y                 173
# Not identified     18
# Probable            2
# -                   2
# Not present         1
# Name: count, dtype: int64
#
# Missing values:  222
# Unique values count: 41
# em_lvi_notes
# Venous                                                             93
# Intramural venous                                                  32
# Lymphatic and venous                                               17
# Venous and lymphatic                                                5
# Lymphatic and intramural venous                                     4
# Extra and intramural venous                                         4
# Venous and Lymphatic                                                3
# Extramural lymphatic and intramural venous                          3
# Lymphatic                                                           3
# Intramural venous invasion present                                  3
# Lymphatic and Venous                                                3
# Intra and extramural venous                                         2
# Perineural infiltration                                             2
# venous                                                              2
# Extramural venous                                                   2
# focal perineural infiltration also seen                             2
# Suspicious foci of lynphatic invasion                               1
# Venous                                                              1
# focal perineural infiltration present                               1
# venous invasion                                                     1
# Intra or extramural venous                                          1
# Lymphatic, single focus extramural                                  1
# Vascular                                                            1
# Suspicious of intramural venous                                     1
# Venous and lymphatic invasion                                       1
# Intramural venous                                                   1
# Focal lymphocapillary space invasion noted.                         1
# Venous focal perineural infiltration also                           1
# Lyphatic                                                            1
# focus of smucosal lymphocapillary space invasion present            1
# Lymphatic not venous                                                1
# Extramural venous and lymphatic                                     1
# Intramural venous, extramural lymphatic                             1
# Venous and intramural lymphatic                                     1
# Submucosal lymphatic invasion                                       1
# Lymphatic and venous, extensive perineural infiltration alos        1
# extra venous, perineural invasion also                              1
# Extramural venous and supiscious focus of extramural lymphatic      1
# S mucosal vascular invasion but no extramural vascular invasion     1
# Lymphatic and venous and intramural venous                          1
# Intramural present, extramural not identified                       1
# Name: count, dtype: int64
#
# Missing values:  2
# Unique values count: 4
# pre-op_radio
# -               324
# N                67
# Y                33
# Not specifed      1
# Name: count, dtype: int64
#
# Missing values:  2
# Unique values count: 5
# pre-op_chemo
# -                                     317
# N                                      89
# Y                                      15
# Not specifed                            3
# Post DXT (docetaxel) (long course)      1
# Name: count, dtype: int64

# %%
#Dropping attributes
df=df.drop(labels=["case_id","days_till_death"],axis=1) #Drop case_id since not needed
#days_till_death cannot be used, since if "days_till_death" = Alive -> died_within_5_years = 0, and 1 otherwise
df=df.drop(labels=["crc_primary_cause_of_death","pM","em_lvi_notes","distance_to_peritoneum_macroscopic_measurement","pre-op_radio","pre-op_chemo"],axis=1) #Too many missing values
df=df.drop(labels=["primary_metastatic","tumour_type"],axis=1) #For primary_metastatic, the whole column is entirely "P". For tumour_type, it is entirely filled with "A/C"

# %%
#Remove all empty records of "died_within_5_years" since results is unknown
df = df[df["died_within_5_years"].isna() == False]
df["died_within_5_years"]=df["died_within_5_years"].astype(int) #Convert to int64 datatype
print(df["died_within_5_years"].value_counts())

#Visualizations of distribution
sns.histplot(df["died_within_5_years"])
# Out:
# died_within_5_years
# 0    264
# 1    161
# Name: count, dtype: int64
# <Axes: xlabel='died_within_5_years', ylabel='Count'>

# %%
#Cleaning the sex attribute
print("Missing values: ",df['sex'].isna().sum())
print(df['sex'].value_counts())
#Data preprocessing to convert sex to binary: M = 1 & F = 0
df['sex'] = df['sex'].map({'M': 1, 'F': 0,})
df.rename(columns={'sex': 'male'}, inplace=True)
df['male'] = df['male'].astype(int)
df['male'].value_counts()

#Visualizations of distribution
sns.histplot(df["male"])
# Out:
# Missing values:  0
# sex
# M    229
# F    196
# Name: count, dtype: int64
# <Axes: xlabel='male', ylabel='Count'>

# %%
#Cleaning the site_of_tumour attribute
print("Missing values: ",df['site_of_tumour'].isna().sum())
#Fill in the missing values with the attribute mode (Categorical values)
df['site_of_tumour']=df['site_of_tumour'].fillna(df['site_of_tumour'].mode()[0])

#Show unique value counts
print("Unique values count:",df['site_of_tumour'].nunique())
print(df['site_of_tumour'].value_counts())

#Replace unique value where counts <=2 with "others"
counts = df['site_of_tumour'].value_counts()
unique = list(counts[counts<=2].index)
df['site_of_tumour']=df['site_of_tumour'].replace(unique,"others")
# Out:
# Missing values:  2
# Unique values count: 32
# site_of_tumour
# rectum                           99
# sigmoid colon                    71
# caecum                           54
# ascending colon                  41
# rectosigmoid                     40
# transverse colon                 22
# upper rectum                     15
# splenic flexure                  14
# lower rectum                     12
# descending colon                 10
# distal sigmoid colon              8
# sigmoid                           7
# hepatic flexure                   7
# caecum/ascending colon            6
# distal sigmoid                    2
# left colon                        1
# proximal descending colon         1
# descending/sigmoid junction??     1
# ascending/transverse colon        1
# proximal ascending colon          1
# lower caecum                      1
# distal descending colon           1
# upper rectum/sigmoid              1
# caecum/ileocaecal valve           1
# caecum/small bowel                1
# proximal transverse colon         1
# right hemicolon                   1
# ileocolic resection??             1
# rectosigmoid junction             1
# appendix                          1
# mid transverse colon              1
# lower descending colon            1
# Name: count, dtype: int64

# %%
#Cleaning the site_of_tumour_grouping attribute
print("Missing values: ",df['site_of_tumour_grouping'].isna().sum())
#Fill in the missing values with the attribute mode (Categorical values)
df['site_of_tumour_grouping']=df['site_of_tumour_grouping'].fillna(df['site_of_tumour_grouping'].mode()[0])

#Show unique value counts
print("Unique values count:",df['site_of_tumour_grouping'].nunique())
print(df['site_of_tumour_grouping'].value_counts())
# Out:
# Missing values:  2
# Unique values count: 8
# site_of_tumour_grouping
# rectum              167
# sigmoid colon        89
# caecum               65
# ascending colon      43
# transverse colon     25
# descending colon     15
# splenic flexure      14
# hepatic flexure       7
# Name: count, dtype: int64

# %%
#Dealing with FAIL values
print(df[(df["kras_ex_2"]=="FAIL") | (df["braf_mutant_status"]=="FAIL")].to_string()) #Inspecting the row

#Dropping these row since, too many FAIL in many column
df=df[(df["kras_ex_2"]!="FAIL") & (df["braf_mutant_status"]!="FAIL")]
# Out:
#      died_within_5_years  age_at_diagnosis  male    site_of_tumour site_of_tumour_grouping kras_ex_2 kras_ex_3 kras_codon_117 nras_ex_2 nras_ex_3 braf_mutant_status  mmr_ihc  mmr_loss_binary stage stage_subgroup    pT  pN differentiation peri_surface_involved em_lvi
# 183                    1                75     0  transverse colon        transverse colon      FAIL      FAIL             WT      FAIL      FAIL          M (V600E)  NO LOSS                0     4              4  ypT3  N0             Mod                     N      N
# 229                    0                50     1      lower rectum                  rectum        WT        WT           FAIL        WT        WT               FAIL  NO LOSS                0     1              1   pT2  N0            Poor                     N      N

# %%
#Dealing with the single instance of M (K117N) value in kras_codon_117 attribute
print(df[df["kras_codon_117"] == "M (K117N)"].to_string()) #Inspecting the instance

df = df[df["kras_codon_117"] != "M (K117N)"] #Dropping the single instance since one sample is unreliable
# Out:
#      died_within_5_years  age_at_diagnosis  male site_of_tumour site_of_tumour_grouping kras_ex_2 kras_ex_3 kras_codon_117 nras_ex_2 nras_ex_3 braf_mutant_status  mmr_ihc  mmr_loss_binary stage stage_subgroup   pT  pN differentiation peri_surface_involved em_lvi
# 267                    1                85     1         rectum                  rectum        WT        WT      M (K117N)        WT        WT                 WT  NO LOSS                0     2             2A  pT3  N0             Mod                     N      Y

# %%
#Cleaning attributes with unnecessary "M ..." values
M_attributes=["kras_ex_2","kras_ex_3","nras_ex_2","nras_ex_3","braf_mutant_status"]
for attribute in M_attributes:
    print(df[attribute].value_counts())
    df[attribute]=df[attribute].str.replace(r'^M.*', 'M', regex=True) #Replace any values start starts with "M" with "M"
    print()
# Out:
# kras_ex_2
# WT          288
# M (G12D)     52
# M (G12V)     29
# M (G13D)     18
# M (G12C)     17
# M (G12S)     12
# M (G12A)      6
# Name: count, dtype: int64
#
# kras_ex_3
# WT          411
# M (Q61L)      4
# M (Q61H)      3
# M (Q61R)      2
# M (G60V)      1
# M (Q61K)      1
# Name: count, dtype: int64
#
# nras_ex_2
# WT              413
# M (G12D)          5
# M (G12A)          2
# M (G12V)          1
# M (codon 14)      1
# Name: count, dtype: int64
#
# nras_ex_3
# WT          404
# FAIL         11
# M (Q61L)      3
# M (Q61K)      2
# M (Q61R)      2
# Name: count, dtype: int64
#
# braf_mutant_status
# WT                        376
# M (V600E)                  37
# M (V600E) - LOW LEVEL       5
# M (V600E)                   1
# M (D584N) - LOW LEVEL       1
# M (S605G) - LOW LEVEL       1
# M (R603Q) - LOW LEVEL)      1
# Name: count, dtype: int64

# %%
#Dealing with binary values in kras_ex_2, kras_ex_3, nras_ex_2,braf_mutant_status, and kras_codon_117
for attribute in ["kras_ex_2","kras_ex_3","nras_ex_2","braf_mutant_status"]:
    df[attribute] = df[attribute].map({'WT': 0, 'M': 1}) #Mapping WT as 0 and M as 1
    print(df[attribute].value_counts())
    print()
df["kras_codon_117"] = df["kras_codon_117"].map({'WT': 0, 'FAIL': 1})
# Out:
# kras_ex_2
# 0    288
# 1    134
# Name: count, dtype: int64
#
# kras_ex_3
# 0    411
# 1     11
# Name: count, dtype: int64
#
# nras_ex_2
# 0    413
# 1      9
# Name: count, dtype: int64
#
# braf_mutant_status
# 0    376
# 1     46
# Name: count, dtype: int64

# %%
#Cleaning the stage and stage_subgroup
print(df[df["stage"].isna() == True].to_string()) #Examaning the row where "stage" is empty
df=df[df["stage"].isna() == False] #Removing the row since too many columns are empty

#Performing ordinal encoding on the attributes
stage_mapping = {'1': 1, '2': 2, '3': 3, '3C': 4, '4': 5}
df['stage'] = df['stage'].map(stage_mapping)

stage_subgroup_map = {
    '1': 1,
    '2A': 2,
    '2B': 3,
    '3A': 4,
    '3B': 5,
    '3C': 6,
    '4': 7
}
df['stage_subgroup'] = df['stage_subgroup'].map(stage_subgroup_map)
# Out:
#      died_within_5_years  age_at_diagnosis  male site_of_tumour site_of_tumour_grouping  kras_ex_2  kras_ex_3  kras_codon_117  nras_ex_2 nras_ex_3  braf_mutant_status  mmr_ihc  mmr_loss_binary stage stage_subgroup   pT   pN differentiation peri_surface_involved em_lvi
# 321                    1                59     1         others                  caecum          0          0               0          1        WT                   0  NO LOSS                0   NaN            NaN  NaN  NaN             NaN                   NaN    NaN

# %%
#Cleaning the pT and pN attribute
attributes = ["pT","pN"]
for attribute in attributes:
    counts = df[attribute].value_counts()
    print (counts) #Print value counts
    other_values = list(counts[counts<=4].index) #Other values which their counts are <=4 (too rare)
    df[attribute] = df[attribute].replace(other_values,"others")
    print()
# Out:
# pT
# pT3     209
# pT2      69
# pT4b     68
# pT4      30
# ypT3     17
# pT1      12
# pT4a     10
# ypT2      3
# ypT1      1
# Pt3       1
# pT        1
# Name: count, dtype: int64
#
# pN
# N0      211
# N1      118
# N2       72
# ypN2      4
# pN1       4
# pN0       4
# pN2       4
# NX        1
# ypN0      1
# Nx        1
# ypN1      1
# Name: count, dtype: int64

# %%
#Cleaning the differentiation attribute
print("Missing values: ", df["differentiation"].isna().sum())
print(df[df["differentiation"].isna()==True].to_string()) #Inspecting the missing value row
df = df[df["differentiation"].isna()==False] #Dropping the row since too many missing values

print(df["differentiation"].unique()) #Look at the unique values

def poor_mod_well(x):
    x=x.lower() #Convert all to lower case
    if "poor" in x and "mod" not in x:
        return 1 #poor
    elif "poor" in x and "mod" in x:
        return 2 #poor_mod
    elif "mod" in x and "well" not in x:
        return 3 #mod
    elif "mod" in x and "well" in x:
        return 4 #mod_well
    else:
        return 5 #well

df["differentiation"]=df["differentiation"].apply(poor_mod_well)

#Visualizations of distribution
sns.histplot(df["differentiation"])
# Out:
# Missing values:  1
#    died_within_5_years  age_at_diagnosis  male site_of_tumour site_of_tumour_grouping  kras_ex_2  kras_ex_3  kras_codon_117  nras_ex_2 nras_ex_3  braf_mutant_status  mmr_ihc  mmr_loss_binary  stage  stage_subgroup   pT      pN differentiation peri_surface_involved em_lvi
# 0                    1                91     0   lower rectum                  rectum          1          0               0          0        WT                   0  NO LOSS                0      1               1  pT2  others             NaN                   NaN    NaN
# ['Mod' 'Poor (areas of moderate)' 'Well (focally mod)'
#  'Mod (focally poor)' 'Mod (foci of poor at invasive front)' 'Poor' 'Well'
#  'Mod (predominantly)' 'Poor (some mod regions with medullary features)'
#  'Well to Mod (mucinous component)'
#  'Mod (leading edge poor with tumour budding)' 'Mod to Poor'
#  'Mod (areas of poor)'
#  'Mod (small focus of mucinous differentiation and small foci of poor)'
#  'Mod (some foci of poor)' 'Mod (some areas of poor)'
#  'Mod (small areas of poorly differentiated)'
#  'Mod (focal poor at invasive front)' 'Mod (foci of poor)'
#  'Mod (areas of mucinous, areas of poor)'
#  'Mod (mucinous areas and occasional signet)'
#  'Poor (focal signet ring cell morph)'
#  'Mod (some mucinous differentiation)' 'Mod-Poor'
#  'Mod (areas of poor differentiation, focal mucinous differentiation)'
#  'Mod (areas of focal poor)' 'Mod to Poor (sig areas of poor)'
#  'Mod (papillary architecture and mucinous differentiation)'
#  'Focally poor but overall mod']
# <Axes: xlabel='differentiation', ylabel='Count'>

# %%
#Cleaning the peri_surface_involved attribute
print(df["peri_surface_involved"].value_counts())
df["peri_surface_involved"]=df["peri_surface_involved"].replace('Not directly visualised but presumed yes',"Y") 

def unknown(x):
    if x != "N" and x!="Y":
        return np.nan
    else:
        return x

df["peri_surface_involved"] = df["peri_surface_involved"].apply(unknown)

df["peri_surface_involved"]=df["peri_surface_involved"].fillna(df["peri_surface_involved"].mode()[0]) #Fill missing values with mode since categorical value
df["peri_surface_involved"]=df["peri_surface_involved"].map({'Y': 1, 'N': 0})

#Visualizations of distribution
sns.histplot(df["peri_surface_involved"])
# Out:
# peri_surface_involved
# N                                           293
# Y                                            93
# Not identified                               13
# -                                            10
# ??                                            3
# N (N/A)                                       1
# Absent                                        1
# Not directly visualised but presumed yes      1
# N?                                            1
# Name: count, dtype: int64
# <Axes: xlabel='peri_surface_involved', ylabel='Count'>

# %%
#Cleaning em_lvi attribute

#Checking missing values
print("Missing values: ",df["em_lvi"].isna().sum())

print(df["em_lvi"].value_counts()) #Inspecting value counts
df["em_lvi"]=df["em_lvi"].replace("Probable","Y")

df["em_lvi"]=df["em_lvi"].apply(unknown)

df["em_lvi"]=df["em_lvi"].fillna(df["em_lvi"].mode()[0]) #Fill missing values with mode since categorical value
df["em_lvi"]=df["em_lvi"].map({'Y': 1, 'N': 0})

#Visualizations of distribution
sns.histplot(df["em_lvi"])
# Out:
# Missing values:  1
# em_lvi
# N                 225
# Y                 171
# Not identified     18
# Probable            2
# -                   2
# Not present         1
# Name: count, dtype: int64
# <Axes: xlabel='em_lvi', ylabel='Count'>

# %%
#Perform one-hot encoding on catergorical attributes
df = pd.get_dummies(df,columns=["site_of_tumour","site_of_tumour_grouping","nras_ex_3","mmr_ihc","pT","pN"],drop_first=True,dtype=int)

# %%
#Scaling the ordinal attributes in the dataset
from sklearn.preprocessing import MinMaxScaler #MinMaxScaler since other values are 0 or 1 (binary value) so scaled values should be between 0-1
ordinal_attributes = ["age_at_diagnosis","stage","stage_subgroup","differentiation"]
scaler = MinMaxScaler()
df[ordinal_attributes] = scaler.fit_transform(df[ordinal_attributes])

# %%
#Splitting the dataset into test, train & val
from sklearn.model_selection import train_test_split
X=df.drop(labels="died_within_5_years",axis=1)
y=df["died_within_5_years"]
#Testing is 15% of original
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42, stratify=y) #Stratify to preserve class ratios

#Val is 15% of original, so of 85%, it is 15% of 85%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=15/85, random_state=42, stratify=y_train)

print("Train:", X_train.shape)
print("Val:", X_val.shape)
print("Test:", X_test.shape)
# Out:
# Train: (293, 48)
# Val: (64, 48)
# Test: (63, 48)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"  # Force CPU
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam
# Out:
# 2025-11-09 12:33:34.581618: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-09 12:33:34.614586: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-09 12:33:35.239662: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
#Defining the architecture
model = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(32, activation="relu"),
    Dense(1, activation="sigmoid")
])
# Out:
# 2025-11-09 12:33:35.345799: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-11-09 12:33:35.345819: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:160] env: CUDA_VISIBLE_DEVICES="-1"
# 2025-11-09 12:33:35.345822: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:163] CUDA_VISIBLE_DEVICES is set to -1 - this hides all GPUs from CUDA
# 2025-11-09 12:33:35.345824: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:171] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2025-11-09 12:33:35.345827: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:176] retrieving CUDA diagnostic information for host: taming3joy-computer
# 2025-11-09 12:33:35.345829: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] hostname: taming3joy-computer
# 2025-11-09 12:33:35.345866: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] libcuda reported version is: 580.95.5
# 2025-11-09 12:33:35.345878: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:194] kernel reported version is: 580.95.5
# 2025-11-09 12:33:35.345880: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:284] kernel version seems to match DSO: 580.95.5

# %%
#Compiling the model
model.compile(
    optimizer=Adam(learning_rate=1e-3),
    loss="binary_crossentropy",
    metrics=["accuracy", tf.keras.metrics.AUC(name="auc")]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │         1,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,601 (6.25 KB)
#  Trainable params: 1,601 (6.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Training the model
history = model.fit(
    X_train,y_train,
    validation_data = (X_val,y_val),
    epochs = 100,
    batch_size = 32,
    verbose=1
)
# Out:
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4949 - auc: 0.5390 - loss: 0.6966 - val_accuracy: 0.5625 - val_auc: 0.5135 - val_loss: 0.6949
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6007 - auc: 0.5827 - loss: 0.6669 - val_accuracy: 0.5781 - val_auc: 0.5458 - val_loss: 0.6714
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6553 - auc: 0.6377 - loss: 0.6432 - val_accuracy: 0.6094 - val_auc: 0.5833 - val_loss: 0.6548
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6621 - auc: 0.6678 - loss: 0.6285 - val_accuracy: 0.6094 - val_auc: 0.6281 - val_loss: 0.6380
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7099 - auc: 0.6938 - loss: 0.6157 - val_accuracy: 0.6406 - val_auc: 0.6698 - val_loss: 0.6231
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7372 - auc: 0.7139 - loss: 0.6030 - val_accuracy: 0.7188 - val_auc: 0.6984 - val_loss: 0.6101
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7509 - auc: 0.7255 - loss: 0.5928 - val_accuracy: 0.7344 - val_auc: 0.7271 - val_loss: 0.5963
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7543 - auc: 0.7341 - loss: 0.5824 - val_accuracy: 0.7500 - val_auc: 0.7344 - val_loss: 0.5855
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7509 - auc: 0.7407 - loss: 0.5737 - val_accuracy: 0.7344 - val_auc: 0.7583 - val_loss: 0.5760
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7577 - auc: 0.7499 - loss: 0.5648 - val_accuracy: 0.7344 - val_auc: 0.7661 - val_loss: 0.5676
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7611 - auc: 0.7605 - loss: 0.5572 - val_accuracy: 0.7188 - val_auc: 0.7740 - val_loss: 0.5615
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7543 - auc: 0.7679 - loss: 0.5514 - val_accuracy: 0.7188 - val_auc: 0.7812 - val_loss: 0.5566
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7577 - auc: 0.7752 - loss: 0.5457 - val_accuracy: 0.7344 - val_auc: 0.7849 - val_loss: 0.5514
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7543 - auc: 0.7761 - loss: 0.5420 - val_accuracy: 0.7344 - val_auc: 0.7854 - val_loss: 0.5473
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7611 - auc: 0.7850 - loss: 0.5360 - val_accuracy: 0.7344 - val_auc: 0.7901 - val_loss: 0.5430
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7577 - auc: 0.7886 - loss: 0.5321 - val_accuracy: 0.7344 - val_auc: 0.7839 - val_loss: 0.5437
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7577 - auc: 0.7910 - loss: 0.5291 - val_accuracy: 0.7344 - val_auc: 0.7745 - val_loss: 0.5430
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7543 - auc: 0.7947 - loss: 0.5252 - val_accuracy: 0.7344 - val_auc: 0.7766 - val_loss: 0.5393
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7543 - auc: 0.7935 - loss: 0.5226 - val_accuracy: 0.7344 - val_auc: 0.7724 - val_loss: 0.5391
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7509 - auc: 0.7975 - loss: 0.5201 - val_accuracy: 0.7344 - val_auc: 0.7786 - val_loss: 0.5367
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7577 - auc: 0.8025 - loss: 0.5157 - val_accuracy: 0.7344 - val_auc: 0.7823 - val_loss: 0.5366
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7577 - auc: 0.8043 - loss: 0.5136 - val_accuracy: 0.7344 - val_auc: 0.7802 - val_loss: 0.5352
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7611 - auc: 0.8084 - loss: 0.5103 - val_accuracy: 0.7344 - val_auc: 0.7818 - val_loss: 0.5325
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7679 - auc: 0.8113 - loss: 0.5081 - val_accuracy: 0.7500 - val_auc: 0.7833 - val_loss: 0.5309
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7713 - auc: 0.8134 - loss: 0.5054 - val_accuracy: 0.7344 - val_auc: 0.7844 - val_loss: 0.5301
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7679 - auc: 0.8157 - loss: 0.5020 - val_accuracy: 0.7344 - val_auc: 0.7828 - val_loss: 0.5295
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7645 - auc: 0.8164 - loss: 0.5007 - val_accuracy: 0.7344 - val_auc: 0.7797 - val_loss: 0.5322
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7645 - auc: 0.8176 - loss: 0.4984 - val_accuracy: 0.7500 - val_auc: 0.7839 - val_loss: 0.5302
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7543 - auc: 0.8167 - loss: 0.4962 - val_accuracy: 0.7500 - val_auc: 0.7859 - val_loss: 0.5268
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7713 - auc: 0.8221 - loss: 0.4922 - val_accuracy: 0.7500 - val_auc: 0.7870 - val_loss: 0.5250
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7679 - auc: 0.8253 - loss: 0.4899 - val_accuracy: 0.7656 - val_auc: 0.7844 - val_loss: 0.5253
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7679 - auc: 0.8274 - loss: 0.4886 - val_accuracy: 0.7344 - val_auc: 0.7844 - val_loss: 0.5312
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7645 - auc: 0.8336 - loss: 0.4857 - val_accuracy: 0.7344 - val_auc: 0.7786 - val_loss: 0.5311
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7713 - auc: 0.8372 - loss: 0.4829 - val_accuracy: 0.7656 - val_auc: 0.7766 - val_loss: 0.5309
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7713 - auc: 0.8391 - loss: 0.4801 - val_accuracy: 0.7656 - val_auc: 0.7766 - val_loss: 0.5297
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7782 - auc: 0.8398 - loss: 0.4780 - val_accuracy: 0.7656 - val_auc: 0.7740 - val_loss: 0.5283
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7850 - auc: 0.8412 - loss: 0.4750 - val_accuracy: 0.7656 - val_auc: 0.7750 - val_loss: 0.5275
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7884 - auc: 0.8453 - loss: 0.4732 - val_accuracy: 0.7500 - val_auc: 0.7781 - val_loss: 0.5270
# Epoch 39/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7816 - auc: 0.8473 - loss: 0.4711 - val_accuracy: 0.7500 - val_auc: 0.7755 - val_loss: 0.5289
# Epoch 40/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7884 - auc: 0.8489 - loss: 0.4695 - val_accuracy: 0.7812 - val_auc: 0.7760 - val_loss: 0.5308
# Epoch 41/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7918 - auc: 0.8509 - loss: 0.4669 - val_accuracy: 0.7812 - val_auc: 0.7797 - val_loss: 0.5310
# Epoch 42/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7918 - auc: 0.8532 - loss: 0.4649 - val_accuracy: 0.7656 - val_auc: 0.7776 - val_loss: 0.5343
# Epoch 43/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7952 - auc: 0.8562 - loss: 0.4624 - val_accuracy: 0.7656 - val_auc: 0.7781 - val_loss: 0.5359
# Epoch 44/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7884 - auc: 0.8578 - loss: 0.4601 - val_accuracy: 0.7812 - val_auc: 0.7760 - val_loss: 0.5389
# Epoch 45/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7884 - auc: 0.8586 - loss: 0.4590 - val_accuracy: 0.7812 - val_auc: 0.7755 - val_loss: 0.5382
# Epoch 46/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7884 - auc: 0.8606 - loss: 0.4560 - val_accuracy: 0.7812 - val_auc: 0.7719 - val_loss: 0.5410
# Epoch 47/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7918 - auc: 0.8628 - loss: 0.4538 - val_accuracy: 0.7656 - val_auc: 0.7698 - val_loss: 0.5428
# Epoch 48/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7884 - auc: 0.8642 - loss: 0.4517 - val_accuracy: 0.7656 - val_auc: 0.7729 - val_loss: 0.5410
# Epoch 49/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7884 - auc: 0.8648 - loss: 0.4498 - val_accuracy: 0.7656 - val_auc: 0.7714 - val_loss: 0.5418
# Epoch 50/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7952 - auc: 0.8660 - loss: 0.4477 - val_accuracy: 0.7656 - val_auc: 0.7703 - val_loss: 0.5417
# Epoch 51/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7918 - auc: 0.8662 - loss: 0.4459 - val_accuracy: 0.7656 - val_auc: 0.7708 - val_loss: 0.5412
# Epoch 52/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7918 - auc: 0.8686 - loss: 0.4440 - val_accuracy: 0.7656 - val_auc: 0.7688 - val_loss: 0.5433
# Epoch 53/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7918 - auc: 0.8709 - loss: 0.4423 - val_accuracy: 0.7656 - val_auc: 0.7609 - val_loss: 0.5476
# Epoch 54/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7986 - auc: 0.8736 - loss: 0.4401 - val_accuracy: 0.7656 - val_auc: 0.7620 - val_loss: 0.5489
# Epoch 55/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8020 - auc: 0.8743 - loss: 0.4383 - val_accuracy: 0.7656 - val_auc: 0.7594 - val_loss: 0.5511
# Epoch 56/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8020 - auc: 0.8744 - loss: 0.4369 - val_accuracy: 0.7656 - val_auc: 0.7609 - val_loss: 0.5508
# Epoch 57/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8020 - auc: 0.8755 - loss: 0.4354 - val_accuracy: 0.7812 - val_auc: 0.7589 - val_loss: 0.5536
# Epoch 58/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8020 - auc: 0.8780 - loss: 0.4330 - val_accuracy: 0.7656 - val_auc: 0.7615 - val_loss: 0.5512
# Epoch 59/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8055 - auc: 0.8781 - loss: 0.4317 - val_accuracy: 0.7656 - val_auc: 0.7630 - val_loss: 0.5507
# Epoch 60/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7986 - auc: 0.8808 - loss: 0.4295 - val_accuracy: 0.7500 - val_auc: 0.7646 - val_loss: 0.5516
# Epoch 61/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8089 - auc: 0.8821 - loss: 0.4285 - val_accuracy: 0.7656 - val_auc: 0.7656 - val_loss: 0.5532
# Epoch 62/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8123 - auc: 0.8863 - loss: 0.4247 - val_accuracy: 0.7500 - val_auc: 0.7646 - val_loss: 0.5524
# Epoch 63/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8055 - auc: 0.8863 - loss: 0.4235 - val_accuracy: 0.7500 - val_auc: 0.7646 - val_loss: 0.5548
# Epoch 64/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8089 - auc: 0.8863 - loss: 0.4225 - val_accuracy: 0.7500 - val_auc: 0.7667 - val_loss: 0.5557
# Epoch 65/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8020 - auc: 0.8851 - loss: 0.4211 - val_accuracy: 0.7656 - val_auc: 0.7641 - val_loss: 0.5570
# Epoch 66/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8123 - auc: 0.8879 - loss: 0.4185 - val_accuracy: 0.7656 - val_auc: 0.7641 - val_loss: 0.5595
# Epoch 67/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8123 - auc: 0.8893 - loss: 0.4170 - val_accuracy: 0.7656 - val_auc: 0.7661 - val_loss: 0.5599
# Epoch 68/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8123 - auc: 0.8915 - loss: 0.4158 - val_accuracy: 0.7656 - val_auc: 0.7630 - val_loss: 0.5647
# Epoch 69/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8157 - auc: 0.8932 - loss: 0.4132 - val_accuracy: 0.7500 - val_auc: 0.7630 - val_loss: 0.5626
# Epoch 70/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8123 - auc: 0.8939 - loss: 0.4119 - val_accuracy: 0.7500 - val_auc: 0.7656 - val_loss: 0.5622
# Epoch 71/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8123 - auc: 0.8969 - loss: 0.4101 - val_accuracy: 0.7500 - val_auc: 0.7661 - val_loss: 0.5626
# Epoch 72/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8123 - auc: 0.8985 - loss: 0.4082 - val_accuracy: 0.7500 - val_auc: 0.7651 - val_loss: 0.5638
# Epoch 73/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8089 - auc: 0.8984 - loss: 0.4063 - val_accuracy: 0.7500 - val_auc: 0.7625 - val_loss: 0.5670
# Epoch 74/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8055 - auc: 0.8982 - loss: 0.4057 - val_accuracy: 0.7500 - val_auc: 0.7630 - val_loss: 0.5662
# Epoch 75/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8123 - auc: 0.9003 - loss: 0.4031 - val_accuracy: 0.7500 - val_auc: 0.7599 - val_loss: 0.5708
# Epoch 76/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8191 - auc: 0.9020 - loss: 0.4019 - val_accuracy: 0.7500 - val_auc: 0.7615 - val_loss: 0.5712
# Epoch 77/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8191 - auc: 0.9032 - loss: 0.4000 - val_accuracy: 0.7500 - val_auc: 0.7594 - val_loss: 0.5759
# Epoch 78/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8191 - auc: 0.9057 - loss: 0.3981 - val_accuracy: 0.7500 - val_auc: 0.7583 - val_loss: 0.5810
# Epoch 79/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8225 - auc: 0.9074 - loss: 0.3972 - val_accuracy: 0.7500 - val_auc: 0.7589 - val_loss: 0.5815
# Epoch 80/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8191 - auc: 0.9083 - loss: 0.3951 - val_accuracy: 0.7500 - val_auc: 0.7615 - val_loss: 0.5775
# Epoch 81/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8157 - auc: 0.9097 - loss: 0.3932 - val_accuracy: 0.7500 - val_auc: 0.7630 - val_loss: 0.5776
# Epoch 82/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8157 - auc: 0.9116 - loss: 0.3910 - val_accuracy: 0.7500 - val_auc: 0.7599 - val_loss: 0.5804
# Epoch 83/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8157 - auc: 0.9106 - loss: 0.3903 - val_accuracy: 0.7500 - val_auc: 0.7641 - val_loss: 0.5817
# Epoch 84/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8157 - auc: 0.9128 - loss: 0.3885 - val_accuracy: 0.7500 - val_auc: 0.7583 - val_loss: 0.5875
# Epoch 85/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8225 - auc: 0.9138 - loss: 0.3864 - val_accuracy: 0.7500 - val_auc: 0.7604 - val_loss: 0.5850
# Epoch 86/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8294 - auc: 0.9145 - loss: 0.3852 - val_accuracy: 0.7500 - val_auc: 0.7635 - val_loss: 0.5870
# Epoch 87/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8225 - auc: 0.9148 - loss: 0.3834 - val_accuracy: 0.7500 - val_auc: 0.7568 - val_loss: 0.5911
# Epoch 88/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8294 - auc: 0.9150 - loss: 0.3828 - val_accuracy: 0.7500 - val_auc: 0.7531 - val_loss: 0.5963
# Epoch 89/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8259 - auc: 0.9156 - loss: 0.3803 - val_accuracy: 0.7500 - val_auc: 0.7609 - val_loss: 0.5891
# Epoch 90/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8294 - auc: 0.9172 - loss: 0.3783 - val_accuracy: 0.7500 - val_auc: 0.7578 - val_loss: 0.5919
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8259 - auc: 0.9182 - loss: 0.3773 - val_accuracy: 0.7500 - val_auc: 0.7583 - val_loss: 0.5953
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8294 - auc: 0.9193 - loss: 0.3755 - val_accuracy: 0.7500 - val_auc: 0.7578 - val_loss: 0.5960
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8362 - auc: 0.9203 - loss: 0.3733 - val_accuracy: 0.7500 - val_auc: 0.7557 - val_loss: 0.5968
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8396 - auc: 0.9208 - loss: 0.3729 - val_accuracy: 0.7500 - val_auc: 0.7505 - val_loss: 0.6024
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8396 - auc: 0.9231 - loss: 0.3706 - val_accuracy: 0.7500 - val_auc: 0.7521 - val_loss: 0.6037
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8396 - auc: 0.9237 - loss: 0.3687 - val_accuracy: 0.7500 - val_auc: 0.7552 - val_loss: 0.6025
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8328 - auc: 0.9248 - loss: 0.3672 - val_accuracy: 0.7500 - val_auc: 0.7547 - val_loss: 0.6030
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8430 - auc: 0.9250 - loss: 0.3655 - val_accuracy: 0.7500 - val_auc: 0.7542 - val_loss: 0.6045
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8430 - auc: 0.9258 - loss: 0.3640 - val_accuracy: 0.7500 - val_auc: 0.7594 - val_loss: 0.6017
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8464 - auc: 0.9269 - loss: 0.3624 - val_accuracy: 0.7500 - val_auc: 0.7599 - val_loss: 0.6040

# %%
pd.DataFrame(history.history)
# Out:
#     accuracy       auc      loss  val_accuracy   val_auc  val_loss
# 0   0.494881  0.538966  0.696648      0.562500  0.513542  0.694878
# 1   0.600683  0.582718  0.666891      0.578125  0.545833  0.671430
# 2   0.655290  0.637739  0.643231      0.609375  0.583333  0.654766
# 3   0.662116  0.667805  0.628465      0.609375  0.628125  0.637985
# 4   0.709898  0.693757  0.615692      0.640625  0.669792  0.623052
# ..       ...       ...       ...           ...       ...       ...
# 95  0.839590  0.923664  0.368699      0.750000  0.755208  0.602518
# 96  0.832765  0.924836  0.367161      0.750000  0.754687  0.603040
# 97  0.843003  0.924960  0.365536      0.750000  0.754167  0.604455
# 98  0.843003  0.925758  0.363961      0.750000  0.759375  0.601666
# 99  0.846416  0.926880  0.362360      0.750000  0.759896  0.603952
#
# [100 rows x 6 columns]

# %%
#Seeing how the metrics change for each epoch
metrics = ["accuracy","auc","loss"]
for metric in metrics:
    plt.plot(history.history[metric], label=f"train {metric}")
    plt.plot(history.history[f"val_{metric}"], label=f"val {metric}")
    plt.legend()
    plt.xlabel("Epoch")
    plt.ylabel(metric)
    plt.show()

# %%
#Making predictions on the testing set
y_prob = model.predict(X_test).ravel()
y_pred = [1 if x>=0.5 else 0 for x in y_prob] #Convert probability to 0 and 1 predictions (Threshold at 0.5)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

#Generating a confusion matrix
cm = confusion_matrix(y_test, y_pred)
labels = ["Negative (0)", "Positive (1)"]
plt.figure(figsize=(5, 4))
sns.heatmap(cm,
            annot=True,
            cmap="Blues",
            xticklabels=labels,
            yticklabels=labels)

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

#Key Metrics
print("Classification report:\n", classification_report(y_test, y_pred, digits=3))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0      0.617     0.744     0.674        39
#            1      0.375     0.250     0.300        24
#
#     accuracy                          0.556        63
#    macro avg      0.496     0.497     0.487        63
# weighted avg      0.525     0.556     0.532        63
