# %%
import pandas as pd
data=pd.read_csv("SR386_labels.csv")

# %%
data.head(10)
# Out:
#    case_id  died_within_5_years days_till_death  crc_primary_cause_of_death  \
# 0        1                  1.0             711                         NaN
# 1        3                  1.0             650                         NaN
# 2        4                  NaN             NaN                         NaN
# 3        6                  0.0           Alive                         NaN
# 4        7                  1.0            1884                         NaN
# 5       10                  0.0           Alive                         NaN
# 6       13                  0.0           Alive                         NaN
# 7       14                  0.0           Alive                         NaN
# 8       15                  1.0             365                         NaN
# 9       16                  0.0           Alive                         NaN
#
#    age_at_diagnosis sex site_of_tumour site_of_tumour_grouping kras_ex_2  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 427 entries, 0 to 426
# Data columns (total 29 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   died_within_5_years                             425 non-null    float64
#  1   days_till_death                                 425 non-null    object
#  2   crc_primary_cause_of_death                      95 non-null     float64
#  3   age_at_diagnosis                                427 non-null    int64
#  4   sex                                             427 non-null    object
#  5   site_of_tumour                                  425 non-null    object
#  6   site_of_tumour_grouping                         425 non-null    object
#  7   kras_ex_2                                       427 non-null    object
#  8   kras_ex_3                                       427 non-null    object
# ...

# %%
import matplotlib.pyplot as plt
data["died_within_5_years"]

# %%
data=data.drop(labels=["case_id"],axis=1)
data
# Out:
#      died_within_5_years days_till_death  crc_primary_cause_of_death  \
# 0                    1.0             711                         NaN
# 1                    1.0             650                         NaN
# 2                    NaN             NaN                         NaN
# 3                    0.0           Alive                         NaN
# 4                    1.0            1884                         NaN
# ..                   ...             ...                         ...
# 422                  0.0           Alive                         NaN
# 423                  1.0            1148                         1.0
# 424                  1.0            1693                         1.0
# 425                  1.0            1296                         1.0
# 426                  0.0           Alive                         NaN
#
#      age_at_diagnosis sex    site_of_tumour site_of_tumour_grouping kras_ex_2  \
# ...
