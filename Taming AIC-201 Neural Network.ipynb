# %%
#import all the neccesary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("SR386_labels.csv")

# %%
df.sample(20)
# Out:
#      case_id  died_within_5_years days_till_death  crc_primary_cause_of_death  \
# 113      166                  1.0            1476                         1.0
# 91       130                  0.0           Alive                         NaN
# 98       140                  0.0           Alive                         NaN
# 288      407                  0.0           Alive                         NaN
# 38        56                  0.0           Alive                         NaN
# 390      535                  0.0           Alive                         NaN
# 195      278                  0.0           Alive                         NaN
# 346      480                  1.0            1567                         1.0
# 417      572                  0.0           Alive                         NaN
# 324      452                  0.0           Alive                         NaN
# 97       138                  0.0           Alive                         NaN
# 426      583                  0.0           Alive                         NaN
# 110      160                  0.0           Alive                         NaN
# 408      560                  0.0           Alive                         NaN
# 11        18                  1.0             215                         NaN
# 129      188                  1.0             295                         1.0
# 136      197                  0.0           Alive                         NaN
# 327      455                  0.0           Alive                         NaN
# 235      335                  0.0           Alive                         NaN
# 59        85                  0.0           Alive                         NaN
#
#      age_at_diagnosis sex    site_of_tumour site_of_tumour_grouping kras_ex_2  \
# 113                62   M  transverse colon        transverse colon        WT
# 91                 59   M            rectum                  rectum        WT
# 98                 61   M     sigmoid colon           sigmoid colon  M (G12C)
# 288                75   M            rectum                  rectum        WT
# 38                 78   M     sigmoid colon           sigmoid colon        WT
# 390                58   M     sigmoid colon           sigmoid colon        WT
# 195                74   M   hepatic flexure         hepatic flexure        WT
# 346                57   F            caecum                  caecum        WT
# 417                78   F            caecum                  caecum  M (G12C)
# 324                74   M            rectum                  rectum        WT
# 97                 76   F      rectosigmoid                  rectum  M (G12V)
# 426                87   F     sigmoid colon           sigmoid colon        WT
# 110                50   M     sigmoid colon           sigmoid colon        WT
# 408                76   M            caecum                  caecum  M (G12V)
# 11                 76   F      rectosigmoid                  rectum        WT
# 129                83   M   hepatic flexure         hepatic flexure  M (G12C)
# 136                63   M      upper rectum                  rectum        WT
# 327                52   F            rectum                  rectum  M (G12S)
# 235                86   M            rectum                  rectum  M (G12S)
# 59                 59   M      upper rectum                  rectum        WT
#
#     kras_ex_3  ...  pN   pM     tumour_type            differentiation  \
# 113        WT  ...  N1  NaN             A/C                        Mod
# 91         WT  ...  N0  cM1             A/C                        Mod
# 98         WT  ...  N2  NaN             A/C                        Mod
# 288        WT  ...  N0  NaN             A/C                        Mod
# 38         WT  ...  N0  NaN             A/C                        Mod
# 390        WT  ...  N0  NaN             A/C                        Mod
# 195        WT  ...  N0  NaN  A/C (mucinous)                        Mod
# 346        WT  ...  N0  NaN             A/C                       Well
# 417        WT  ...  N0  NaN             A/C                        Mod
# 324        WT  ...  N1  NaN             A/C  Mod (areas of focal poor)
# 97         WT  ...  N1  NaN             A/C                        Mod
# 426        WT  ...  N0  NaN             A/C                        Mod
# 110        WT  ...  N0  NaN             A/C                        Mod
# 408        WT  ...  N0  NaN  A/C (mucinous)                        Mod
# 11         WT  ...  N0  NaN             A/C                        Mod
# 129        WT  ...  N2  NaN             A/C         Mod (focally poor)
# 136        WT  ...  N0  NaN             A/C    Mod (some foci of poor)
# 327        WT  ...  N1  NaN             A/C                        Mod
# 235        WT  ...  N1  NaN             A/C                        Mod
# 59         WT  ...  N0  NaN             A/C                        Mod
#
#     peri_surface_involved  distance_to_peritoneum_macroscopic_measurement  \
# 113                     Y                                             0mm
# 91                      N                                            18mm
# 98                      N                                             1mm
# 288                     N                                               -
# 38                      N                                           0.5mm
# 390                     -                                          <0.5mm
# 195                     N                                             2mm
# 346                     Y                                             0mm
# 417                     N                                           0.5mm
# 324                     N                                               -
# 97                      N                                           >10mm
# 426                     -                                             1mm
# 110                     N                                           1.3mm
# 408                     Y                                             NaN
# 11                      N                                    Not assessed
# 129                     Y                                             0mm
# 136                     N                                             5mm
# 327                     Y                                             0mm
# 235                     N                                               -
# 59                 Absent                                            15mm
#
#              em_lvi                 em_lvi_notes pre-op_radio pre-op_chemo
# 113               Y                       Venous            -            -
# 91                N                          NaN            Y            N
# 98                N            Intramural venous            -            -
# 288               N            Intramural venous            Y            N
# 38                N            Intramural venous            -            -
# 390               Y  Extra and intramural venous            -            -
# 195               N                          NaN            -            -
# 346               N                          NaN            -            -
# 417               N                          NaN            -            -
# 324               Y         Lymphatic and venous            -            -
# 97                N                          NaN            -            N
# 426               N            Intramural venous            -            -
# 110               N                          NaN            -            -
# 408  Not identified                          NaN            -            -
# 11                N                          NaN            N            Y
# 129               Y         Lymphatic and venous            -            -
# 136               N                          NaN            N            N
# 327               Y                       Venous            Y            N
# 235               N            Intramural venous            N            N
# 59                N            Intramural venous            -            -
#
# [20 rows x 30 columns]

# %%
#Initial EDA of data
df.info() #Show datatypes
df.describe(include='all').transpose()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 420 entries, 1 to 426
# Data columns (total 49 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   died_within_5_years                       420 non-null    int64
#  1   age_at_diagnosis                          420 non-null    float64
#  2   male                                      420 non-null    int64
#  3   kras_ex_2                                 420 non-null    int64
#  4   kras_ex_3                                 420 non-null    int64
#  5   kras_codon_117                            420 non-null    int64
#  6   nras_ex_2                                 420 non-null    int64
#  7   braf_mutant_status                        420 non-null    int64
#  8   mmr_loss_binary                           420 non-null    int64
#  9   stage                                     420 non-null    float64
#  10  stage_subgroup                            420 non-null    float64
#  11  differentiation                           420 non-null    float64
#  12  peri_surface_involved                     420 non-null    int64
#  13  em_lvi                                    420 non-null    int64
#  14  site_of_tumour_caecum                     420 non-null    int64
#  15  site_of_tumour_caecum/ascending colon     420 non-null    int64
#  16  site_of_tumour_descending colon           420 non-null    int64
#  17  site_of_tumour_distal sigmoid colon       420 non-null    int64
#  18  site_of_tumour_hepatic flexure            420 non-null    int64
#  19  site_of_tumour_lower rectum               420 non-null    int64
#  20  site_of_tumour_others                     420 non-null    int64
#  21  site_of_tumour_rectosigmoid               420 non-null    int64
#  22  site_of_tumour_rectum                     420 non-null    int64
#  23  site_of_tumour_sigmoid                    420 non-null    int64
#  24  site_of_tumour_sigmoid colon              420 non-null    int64
#  25  site_of_tumour_splenic flexure            420 non-null    int64
#  26  site_of_tumour_transverse colon           420 non-null    int64
#  27  site_of_tumour_upper rectum               420 non-null    int64
#  28  site_of_tumour_grouping_caecum            420 non-null    int64
#  29  site_of_tumour_grouping_descending colon  420 non-null    int64
#  30  site_of_tumour_grouping_hepatic flexure   420 non-null    int64
#  31  site_of_tumour_grouping_rectum            420 non-null    int64
#  32  site_of_tumour_grouping_sigmoid colon     420 non-null    int64
#  33  site_of_tumour_grouping_splenic flexure   420 non-null    int64
#  34  site_of_tumour_grouping_transverse colon  420 non-null    int64
#  35  nras_ex_3_M                               420 non-null    int64
#  36  nras_ex_3_WT                              420 non-null    int64
#  37  mmr_ihc_NO LOSS                           420 non-null    int64
#  38  mmr_ihc_PMS2 LOSS                         420 non-null    int64
#  39  pT_pT1                                    420 non-null    int64
#  40  pT_pT2                                    420 non-null    int64
#  41  pT_pT3                                    420 non-null    int64
#  42  pT_pT4                                    420 non-null    int64
#  43  pT_pT4a                                   420 non-null    int64
#  44  pT_pT4b                                   420 non-null    int64
#  45  pT_ypT3                                   420 non-null    int64
#  46  pN_N1                                     420 non-null    int64
#  47  pN_N2                                     420 non-null    int64
#  48  pN_others                                 420 non-null    int64
# dtypes: float64(4), int64(45)
# memory usage: 164.1 KB
#                                           count      mean       std  min  \
# died_within_5_years                       420.0  0.373810  0.484391  0.0
# age_at_diagnosis                          420.0  0.545238  0.186124  0.0
# male                                      420.0  0.538095  0.499141  0.0
# kras_ex_2                                 420.0  0.316667  0.465731  0.0
# kras_ex_3                                 420.0  0.026190  0.159892  0.0
# kras_codon_117                            420.0  0.052381  0.223060  0.0
# nras_ex_2                                 420.0  0.019048  0.136855  0.0
# braf_mutant_status                        420.0  0.109524  0.312668  0.0
# mmr_loss_binary                           420.0  0.076190  0.265619  0.0
# stage                                     420.0  0.408333  0.265210  0.0
# stage_subgroup                            420.0  0.443651  0.318691  0.0
# differentiation                           420.0  0.453571  0.200504  0.0
# peri_surface_involved                     420.0  0.223810  0.417293  0.0
# em_lvi                                    420.0  0.411905  0.492765  0.0
# site_of_tumour_caecum                     420.0  0.128571  0.335124  0.0
# site_of_tumour_caecum/ascending colon     420.0  0.014286  0.118808  0.0
# site_of_tumour_descending colon           420.0  0.023810  0.152637  0.0
# site_of_tumour_distal sigmoid colon       420.0  0.019048  0.136855  0.0
# site_of_tumour_hepatic flexure            420.0  0.016667  0.128172  0.0
# site_of_tumour_lower rectum               420.0  0.023810  0.152637  0.0
# site_of_tumour_others                     420.0  0.042857  0.202776  0.0
# site_of_tumour_rectosigmoid               420.0  0.095238  0.293894  0.0
# site_of_tumour_rectum                     420.0  0.233333  0.423457  0.0
# site_of_tumour_sigmoid                    420.0  0.016667  0.128172  0.0
# site_of_tumour_sigmoid colon              420.0  0.169048  0.375241  0.0
# site_of_tumour_splenic flexure            420.0  0.033333  0.179720  0.0
# site_of_tumour_transverse colon           420.0  0.050000  0.218205  0.0
# site_of_tumour_upper rectum               420.0  0.035714  0.185798  0.0
# site_of_tumour_grouping_caecum            420.0  0.152381  0.359818  0.0
# site_of_tumour_grouping_descending colon  420.0  0.035714  0.185798  0.0
# site_of_tumour_grouping_hepatic flexure   420.0  0.016667  0.128172  0.0
# site_of_tumour_grouping_rectum            420.0  0.390476  0.488439  0.0
# site_of_tumour_grouping_sigmoid colon     420.0  0.211905  0.409145  0.0
# site_of_tumour_grouping_splenic flexure   420.0  0.033333  0.179720  0.0
# site_of_tumour_grouping_transverse colon  420.0  0.057143  0.232392  0.0
# nras_ex_3_M                               420.0  0.016667  0.128172  0.0
# nras_ex_3_WT                              420.0  0.957143  0.202776  0.0
# mmr_ihc_NO LOSS                           420.0  0.923810  0.265619  0.0
# mmr_ihc_PMS2 LOSS                         420.0  0.009524  0.097240  0.0
# pT_pT1                                    420.0  0.028571  0.166797  0.0
# pT_pT2                                    420.0  0.161905  0.368803  0.0
# pT_pT3                                    420.0  0.497619  0.500591  0.0
# pT_pT4                                    420.0  0.071429  0.257847  0.0
# pT_pT4a                                   420.0  0.023810  0.152637  0.0
# pT_pT4b                                   420.0  0.161905  0.368803  0.0
# pT_ypT3                                   420.0  0.040476  0.197308  0.0
# pN_N1                                     420.0  0.280952  0.450000  0.0
# pN_N2                                     420.0  0.171429  0.377333  0.0
# pN_others                                 420.0  0.045238  0.208074  0.0
#
#                                                25%     50%       75%  max
# died_within_5_years                       0.000000  0.0000  1.000000  1.0
# age_at_diagnosis                          0.406250  0.5625  0.687500  1.0
# male                                      0.000000  1.0000  1.000000  1.0
# kras_ex_2                                 0.000000  0.0000  1.000000  1.0
# kras_ex_3                                 0.000000  0.0000  0.000000  1.0
# kras_codon_117                            0.000000  0.0000  0.000000  1.0
# nras_ex_2                                 0.000000  0.0000  0.000000  1.0
# braf_mutant_status                        0.000000  0.0000  0.000000  1.0
# mmr_loss_binary                           0.000000  0.0000  0.000000  1.0
# stage                                     0.250000  0.5000  0.500000  1.0
# stage_subgroup                            0.166667  0.5000  0.666667  1.0
# differentiation                           0.500000  0.5000  0.500000  1.0
# peri_surface_involved                     0.000000  0.0000  0.000000  1.0
# em_lvi                                    0.000000  0.0000  1.000000  1.0
# site_of_tumour_caecum                     0.000000  0.0000  0.000000  1.0
# site_of_tumour_caecum/ascending colon     0.000000  0.0000  0.000000  1.0
# site_of_tumour_descending colon           0.000000  0.0000  0.000000  1.0
# site_of_tumour_distal sigmoid colon       0.000000  0.0000  0.000000  1.0
# site_of_tumour_hepatic flexure            0.000000  0.0000  0.000000  1.0
# site_of_tumour_lower rectum               0.000000  0.0000  0.000000  1.0
# site_of_tumour_others                     0.000000  0.0000  0.000000  1.0
# site_of_tumour_rectosigmoid               0.000000  0.0000  0.000000  1.0
# site_of_tumour_rectum                     0.000000  0.0000  0.000000  1.0
# site_of_tumour_sigmoid                    0.000000  0.0000  0.000000  1.0
# site_of_tumour_sigmoid colon              0.000000  0.0000  0.000000  1.0
# site_of_tumour_splenic flexure            0.000000  0.0000  0.000000  1.0
# site_of_tumour_transverse colon           0.000000  0.0000  0.000000  1.0
# site_of_tumour_upper rectum               0.000000  0.0000  0.000000  1.0
# site_of_tumour_grouping_caecum            0.000000  0.0000  0.000000  1.0
# site_of_tumour_grouping_descending colon  0.000000  0.0000  0.000000  1.0
# site_of_tumour_grouping_hepatic flexure   0.000000  0.0000  0.000000  1.0
# site_of_tumour_grouping_rectum            0.000000  0.0000  1.000000  1.0
# site_of_tumour_grouping_sigmoid colon     0.000000  0.0000  0.000000  1.0
# site_of_tumour_grouping_splenic flexure   0.000000  0.0000  0.000000  1.0
# site_of_tumour_grouping_transverse colon  0.000000  0.0000  0.000000  1.0
# nras_ex_3_M                               0.000000  0.0000  0.000000  1.0
# nras_ex_3_WT                              1.000000  1.0000  1.000000  1.0
# mmr_ihc_NO LOSS                           1.000000  1.0000  1.000000  1.0
# mmr_ihc_PMS2 LOSS                         0.000000  0.0000  0.000000  1.0
# pT_pT1                                    0.000000  0.0000  0.000000  1.0
# pT_pT2                                    0.000000  0.0000  0.000000  1.0
# pT_pT3                                    0.000000  0.0000  1.000000  1.0
# pT_pT4                                    0.000000  0.0000  0.000000  1.0
# pT_pT4a                                   0.000000  0.0000  0.000000  1.0
# pT_pT4b                                   0.000000  0.0000  0.000000  1.0
# pT_ypT3                                   0.000000  0.0000  0.000000  1.0
# pN_N1                                     0.000000  0.0000  1.000000  1.0
# pN_N2                                     0.000000  0.0000  0.000000  1.0
# pN_others                                 0.000000  0.0000  0.000000  1.0

# %%
df.isna().sum()
# Out:
# case_id                                             0
# died_within_5_years                                 2
# days_till_death                                     2
# crc_primary_cause_of_death                        332
# age_at_diagnosis                                    0
# sex                                                 0
# site_of_tumour                                      2
# site_of_tumour_grouping                             2
# kras_ex_2                                           0
# kras_ex_3                                           0
# kras_codon_117                                      0
# nras_ex_2                                           0
# nras_ex_3                                           0
# braf_mutant_status                                  0
# mmr_ihc                                             0
# mmr_loss_binary                                     0
# primary_metastatic                                  0
# stage                                               1
# stage_subgroup                                      1
# pT                                                  1
# pN                                                  1
# pM                                                393
# tumour_type                                         2
# differentiation                                     2
# peri_surface_involved                               6
# distance_to_peritoneum_macroscopic_measurement     25
# em_lvi                                              3
# em_lvi_notes                                      222
# pre-op_radio                                        2
# pre-op_chemo                                        2
# dtype: int64

# %%
#EDA of the attributes
for attribute in df.columns: #After age_at_diagnosis attribute
    print("Missing values: ",df[attribute].isna().sum())
    #Show unique value counts
    print("Unique values count:",df[attribute].nunique())
    print(df[attribute].value_counts())
    print()
# Out:
# Missing values:  0
# Unique values count: 427
# case_id
# 1      1
# 3      1
# 4      1
# 6      1
# 7      1
#       ..
# 578    1
# 580    1
# 581    1
# 582    1
# 583    1
# Name: count, Length: 427, dtype: int64
#
# Missing values:  2
# Unique values count: 2
# died_within_5_years
# 0.0    264
# 1.0    161
# Name: count, dtype: int64
#
# Missing values:  2
# Unique values count: 157
# days_till_death
# Alive    264
# 1188       2
# 350        2
# 643        2
# 331        2
#         ...
# 442        1
# 159        1
# 1148       1
# 1693       1
# 1296       1
# Name: count, Length: 157, dtype: int64
#
# Missing values:  332
# Unique values count: 1
# crc_primary_cause_of_death
# 1.0    95
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 56
# age_at_diagnosis
# 75    21
# 76    17
# 71    17
# 59    17
# 61    16
# 69    15
# 66    15
# 74    14
# 83    13
# 58    13
# 80    13
# 63    12
# 78    11
# 67    11
# 82    10
# 79    10
# 55    10
# 77    10
# 60    10
# 81    10
# 70    10
# 65     9
# 68     9
# 64     8
# 52     8
# 57     8
# 72     8
# 62     7
# 49     7
# 73     7
# 50     7
# 85     7
# 86     7
# 53     6
# 54     6
# 87     5
# 39     5
# 56     4
# 84     4
# 43     3
# 88     3
# 51     3
# 48     3
# 91     2
# 92     2
# 42     2
# 33     2
# 46     2
# 89     1
# 47     1
# 97     1
# 44     1
# 40     1
# 38     1
# 95     1
# 37     1
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 2
# sex
# M    230
# F    197
# Name: count, dtype: int64
#
# Missing values:  2
# Unique values count: 32
# site_of_tumour
# rectum                           98
# sigmoid colon                    71
# caecum                           54
# ascending colon                  41
# rectosigmoid                     40
# transverse colon                 22
# upper rectum                     15
# splenic flexure                  14
# lower rectum                     12
# descending colon                 11
# distal sigmoid colon              8
# sigmoid                           7
# hepatic flexure                   7
# caecum/ascending colon            6
# distal sigmoid                    2
# left colon                        1
# proximal descending colon         1
# descending/sigmoid junction??     1
# ascending/transverse colon        1
# proximal ascending colon          1
# lower caecum                      1
# distal descending colon           1
# upper rectum/sigmoid              1
# caecum/ileocaecal valve           1
# caecum/small bowel                1
# proximal transverse colon         1
# right hemicolon                   1
# ileocolic resection??             1
# rectosigmoid junction             1
# appendix                          1
# mid transverse colon              1
# lower descending colon            1
# Name: count, dtype: int64
#
# Missing values:  2
# Unique values count: 8
# site_of_tumour_grouping
# rectum              166
# sigmoid colon        89
# caecum               65
# ascending colon      43
# transverse colon     25
# descending colon     16
# splenic flexure      14
# hepatic flexure       7
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 8
# kras_ex_2
# WT          291
# M (G12D)     53
# M (G12V)     29
# M (G13D)     18
# M (G12C)     17
# M (G12S)     12
# M (G12A)      6
# FAIL          1
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 7
# kras_ex_3
# WT          415
# M (Q61L)      4
# M (Q61H)      3
# M (Q61R)      2
# M (G60V)      1
# M (Q61K)      1
# FAIL          1
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 3
# kras_codon_117
# WT           403
# FAIL          23
# M (K117N)      1
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 6
# nras_ex_2
# WT              417
# M (G12D)          5
# M (G12A)          2
# FAIL              1
# M (G12V)          1
# M (codon 14)      1
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 5
# nras_ex_3
# WT          408
# FAIL         12
# M (Q61L)      3
# M (Q61K)      2
# M (Q61R)      2
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 8
# braf_mutant_status
# WT                        379
# M (V600E)                  38
# M (V600E) - LOW LEVEL       5
# M (V600E)                   1
# FAIL                        1
# M (D584N) - LOW LEVEL       1
# M (S605G) - LOW LEVEL       1
# M (R603Q) - LOW LEVEL)      1
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 3
# mmr_ihc
# NO LOSS            395
# MLH1, PMS2 LOSS     28
# PMS2 LOSS            4
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 2
# mmr_loss_binary
# 0    395
# 1     32
# Name: count, dtype: int64
#
# Missing values:  0
# Unique values count: 1
# primary_metastatic
# P    427
# Name: count, dtype: int64
#
# Missing values:  1
# Unique values count: 5
# stage
# 2     153
# 3     120
# 3C     73
# 1      60
# 4      20
# Name: count, dtype: int64
#
# Missing values:  1
# Unique values count: 7
# stage_subgroup
# 2A    120
# 3B     96
# 3C     73
# 1      60
# 2B     33
# 3A     24
# 4      20
# Name: count, dtype: int64
#
# Missing values:  1
# Unique values count: 11
# pT
# pT3     210
# pT2      71
# pT4b     69
# pT4      30
# ypT3     18
# pT1      12
# pT4a     10
# ypT2      3
# ypT1      1
# Pt3       1
# pT        1
# Name: count, dtype: int64
#
# Missing values:  1
# Unique values count: 11
# pN
# N0      216
# N1      118
# N2       72
# ypN2      4
# pN1       4
# pN0       4
# pN2       4
# NX        1
# ypN0      1
# Nx        1
# ypN1      1
# Name: count, dtype: int64
#
# Missing values:  393
# Unique values count: 6
# pM
# M1             19
# MX              8
# Mx              4
# cM1             1
# cM1?            1
# cM1 (liver)     1
# Name: count, dtype: int64
#
# Missing values:  2
# Unique values count: 17
# tumour_type
# A/C                                                369
# A/C (mucinous)                                      18
# A/C (Mucinous)                                      13
# A/C (focally mucinous)                               7
# A/C (mucinous component)                             6
# A/C (mucinous with signet ring differentiation)      1
# Multifocal A/C                                       1
# A/C (mucinous and signet ring component)             1
# A/C (medullary like features)                        1
# A/C (villous adenoma like)                           1
# A/C (prominent mucinous differentitation)            1
# A/C (medullary features)                             1
# A/C (mucinous, predominantly signet ring)            1
# A/C (Medullary)                                      1
# A/C (residual)                                       1
# A/C (serrated morph and mucinous component)          1
# A/C (focally mucinous in <10%)                       1
# Name: count, dtype: int64
#
# Missing values:  2
# Unique values count: 29
# differentiation
# Mod                                                                     324
# Poor                                                                     44
# Well                                                                     19
# Mod (focally poor)                                                        6
# Mod to Poor                                                               4
# Mod (foci of poor at invasive front)                                      2
# Mod (predominantly)                                                       2
# Mod-Poor                                                                  2
# Mod (some areas of poor)                                                  2
# Poor (some mod regions with medullary features)                           1
# Well to Mod (mucinous component)                                          1
# Poor (areas of moderate)                                                  1
# Well (focally mod)                                                        1
# Mod (areas of poor)                                                       1
# Mod (leading edge poor with tumour budding)                               1
# Mod (some foci of poor)                                                   1
# Mod (small focus of mucinous differentiation and small foci of poor)      1
# Mod (focal poor at invasive front)                                        1
# Mod (foci of poor)                                                        1
# Mod (areas of mucinous, areas of poor)                                    1
# Mod (small areas of poorly differentiated)                                1
# Mod (mucinous areas and occasional signet)                                1
# Poor (focal signet ring cell morph)                                       1
# Mod (some mucinous differentiation)                                       1
# Mod (areas of poor differentiation, focal mucinous differentiation)       1
# Mod (areas of focal poor)                                                 1
# Mod to Poor (sig areas of poor)                                           1
# Mod (papillary architecture and mucinous differentiation)                 1
# Focally poor but overall mod                                              1
# Name: count, dtype: int64
#
# Missing values:  6
# Unique values count: 9
# peri_surface_involved
# N                                           297
# Y                                            94
# Not identified                               13
# -                                            10
# ??                                            3
# N (N/A)                                       1
# Absent                                        1
# Not directly visualised but presumed yes      1
# N?                                            1
# Name: count, dtype: int64
#
# Missing values:  25
# Unique values count: 79
# distance_to_peritoneum_macroscopic_measurement
# 0mm                       72
# -                         42
# 0.2mm                     15
# 0.3mm                     14
# <1mm                      14
#                           ..
# Clear but not measured     1
# 20mm                       1
# <0.2mm                     1
# About 5mm                  1
# 4.5mm                      1
# Name: count, Length: 79, dtype: int64
#
# Missing values:  3
# Unique values count: 6
# em_lvi
# N                 228
# Y                 173
# Not identified     18
# Probable            2
# -                   2
# Not present         1
# Name: count, dtype: int64
#
# Missing values:  222
# Unique values count: 41
# em_lvi_notes
# Venous                                                             93
# Intramural venous                                                  32
# Lymphatic and venous                                               17
# Venous and lymphatic                                                5
# Lymphatic and intramural venous                                     4
# Extra and intramural venous                                         4
# Venous and Lymphatic                                                3
# Extramural lymphatic and intramural venous                          3
# Lymphatic                                                           3
# Intramural venous invasion present                                  3
# Lymphatic and Venous                                                3
# Intra and extramural venous                                         2
# Perineural infiltration                                             2
# venous                                                              2
# Extramural venous                                                   2
# focal perineural infiltration also seen                             2
# Suspicious foci of lynphatic invasion                               1
# Venous                                                              1
# focal perineural infiltration present                               1
# venous invasion                                                     1
# Intra or extramural venous                                          1
# Lymphatic, single focus extramural                                  1
# Vascular                                                            1
# Suspicious of intramural venous                                     1
# Venous and lymphatic invasion                                       1
# Intramural venous                                                   1
# Focal lymphocapillary space invasion noted.                         1
# Venous focal perineural infiltration also                           1
# Lyphatic                                                            1
# focus of smucosal lymphocapillary space invasion present            1
# Lymphatic not venous                                                1
# Extramural venous and lymphatic                                     1
# Intramural venous, extramural lymphatic                             1
# Venous and intramural lymphatic                                     1
# Submucosal lymphatic invasion                                       1
# Lymphatic and venous, extensive perineural infiltration alos        1
# extra venous, perineural invasion also                              1
# Extramural venous and supiscious focus of extramural lymphatic      1
# S mucosal vascular invasion but no extramural vascular invasion     1
# Lymphatic and venous and intramural venous                          1
# Intramural present, extramural not identified                       1
# Name: count, dtype: int64
#
# Missing values:  2
# Unique values count: 4
# pre-op_radio
# -               324
# N                67
# Y                33
# Not specifed      1
# Name: count, dtype: int64
#
# Missing values:  2
# Unique values count: 5
# pre-op_chemo
# -                                     317
# N                                      89
# Y                                      15
# Not specifed                            3
# Post DXT (docetaxel) (long course)      1
# Name: count, dtype: int64

# %%
#Dropping attributes
df=df.drop(labels=["case_id","days_till_death"],axis=1) #Drop case_id since not needed
#days_till_death cannot be used, since if "days_till_death" = Alive -> died_within_5_years = 0, and 1 otherwise
df=df.drop(labels=["crc_primary_cause_of_death","pM","em_lvi_notes","distance_to_peritoneum_macroscopic_measurement","pre-op_radio","pre-op_chemo"],axis=1) #Too many missing values
df=df.drop(labels=["primary_metastatic","tumour_type"],axis=1) #For primary_metastatic, the whole column is entirely "P". For tumour_type, it is entirely filled with "A/C"

# %%
#Remove all empty records of "died_within_5_years" since results is unknown
df = df[df["died_within_5_years"].isna() == False]
df["died_within_5_years"]=df["died_within_5_years"].astype(int) #Convert to int64 datatype
print(df["died_within_5_years"].value_counts())

#Visualizations of distribution
sns.histplot(df["died_within_5_years"])
# Out:
# died_within_5_years
# 0    264
# 1    161
# Name: count, dtype: int64
# <Axes: xlabel='died_within_5_years', ylabel='Count'>

# %%
#Cleaning the sex attribute
print("Missing values: ",df['sex'].isna().sum())
print(df['sex'].value_counts())
#Data preprocessing to convert sex to binary: M = 1 & F = 0
df['sex'] = df['sex'].map({'M': 1, 'F': 0,})
df.rename(columns={'sex': 'male'}, inplace=True)
df['male'] = df['male'].astype(int)
df['male'].value_counts()

#Visualizations of distribution
sns.histplot(df["male"])
# Out:
# Missing values:  0
# sex
# M    229
# F    196
# Name: count, dtype: int64
# <Axes: xlabel='male', ylabel='Count'>

# %%
#Cleaning the site_of_tumour attribute
print("Missing values: ",df['site_of_tumour'].isna().sum())
#Fill in the missing values with the attribute mode (Categorical values)
df['site_of_tumour']=df['site_of_tumour'].fillna(df['site_of_tumour'].mode()[0])

#Show unique value counts
print("Unique values count:",df['site_of_tumour'].nunique())
print(df['site_of_tumour'].value_counts())

#Replace unique value where counts <=2 with "others"
counts = df['site_of_tumour'].value_counts()
unique = list(counts[counts<=2].index)
df['site_of_tumour']=df['site_of_tumour'].replace(unique,"others")
# Out:
# Missing values:  2
# Unique values count: 32
# site_of_tumour
# rectum                           99
# sigmoid colon                    71
# caecum                           54
# ascending colon                  41
# rectosigmoid                     40
# transverse colon                 22
# upper rectum                     15
# splenic flexure                  14
# lower rectum                     12
# descending colon                 10
# distal sigmoid colon              8
# sigmoid                           7
# hepatic flexure                   7
# caecum/ascending colon            6
# distal sigmoid                    2
# left colon                        1
# proximal descending colon         1
# descending/sigmoid junction??     1
# ascending/transverse colon        1
# proximal ascending colon          1
# lower caecum                      1
# distal descending colon           1
# upper rectum/sigmoid              1
# caecum/ileocaecal valve           1
# caecum/small bowel                1
# proximal transverse colon         1
# right hemicolon                   1
# ileocolic resection??             1
# rectosigmoid junction             1
# appendix                          1
# mid transverse colon              1
# lower descending colon            1
# Name: count, dtype: int64

# %%
#Cleaning the site_of_tumour_grouping attribute
print("Missing values: ",df['site_of_tumour_grouping'].isna().sum())
#Fill in the missing values with the attribute mode (Categorical values)
df['site_of_tumour_grouping']=df['site_of_tumour_grouping'].fillna(df['site_of_tumour_grouping'].mode()[0])

#Show unique value counts
print("Unique values count:",df['site_of_tumour_grouping'].nunique())
print(df['site_of_tumour_grouping'].value_counts())
# Out:
# Missing values:  2
# Unique values count: 8
# site_of_tumour_grouping
# rectum              167
# sigmoid colon        89
# caecum               65
# ascending colon      43
# transverse colon     25
# descending colon     15
# splenic flexure      14
# hepatic flexure       7
# Name: count, dtype: int64

# %%
#Dealing with FAIL values
print(df[(df["kras_ex_2"]=="FAIL") | (df["braf_mutant_status"]=="FAIL")].to_string()) #Inspecting the row

#Dropping these row since, too many FAIL in many column
df=df[(df["kras_ex_2"]!="FAIL") & (df["braf_mutant_status"]!="FAIL")]
# Out:
#      died_within_5_years  age_at_diagnosis  male    site_of_tumour site_of_tumour_grouping kras_ex_2 kras_ex_3 kras_codon_117 nras_ex_2 nras_ex_3 braf_mutant_status  mmr_ihc  mmr_loss_binary stage stage_subgroup    pT  pN differentiation peri_surface_involved em_lvi
# 183                    1                75     0  transverse colon        transverse colon      FAIL      FAIL             WT      FAIL      FAIL          M (V600E)  NO LOSS                0     4              4  ypT3  N0             Mod                     N      N
# 229                    0                50     1      lower rectum                  rectum        WT        WT           FAIL        WT        WT               FAIL  NO LOSS                0     1              1   pT2  N0            Poor                     N      N

# %%
#Dealing with the single instance of M (K117N) value in kras_codon_117 attribute
print(df[df["kras_codon_117"] == "M (K117N)"].to_string()) #Inspecting the instance

df = df[df["kras_codon_117"] != "M (K117N)"] #Dropping the single instance since one sample is unreliable
# Out:
#      died_within_5_years  age_at_diagnosis  male site_of_tumour site_of_tumour_grouping kras_ex_2 kras_ex_3 kras_codon_117 nras_ex_2 nras_ex_3 braf_mutant_status  mmr_ihc  mmr_loss_binary stage stage_subgroup   pT  pN differentiation peri_surface_involved em_lvi
# 267                    1                85     1         rectum                  rectum        WT        WT      M (K117N)        WT        WT                 WT  NO LOSS                0     2             2A  pT3  N0             Mod                     N      Y

# %%
#Cleaning attributes with unnecessary "M ..." values
M_attributes=["kras_ex_2","kras_ex_3","nras_ex_2","nras_ex_3","braf_mutant_status"]
for attribute in M_attributes:
    print(df[attribute].value_counts())
    df[attribute]=df[attribute].str.replace(r'^M.*', 'M', regex=True) #Replace any values start starts with "M" with "M"
    print()
# Out:
# kras_ex_2
# WT          288
# M (G12D)     52
# M (G12V)     29
# M (G13D)     18
# M (G12C)     17
# M (G12S)     12
# M (G12A)      6
# Name: count, dtype: int64
#
# kras_ex_3
# WT          411
# M (Q61L)      4
# M (Q61H)      3
# M (Q61R)      2
# M (G60V)      1
# M (Q61K)      1
# Name: count, dtype: int64
#
# nras_ex_2
# WT              413
# M (G12D)          5
# M (G12A)          2
# M (G12V)          1
# M (codon 14)      1
# Name: count, dtype: int64
#
# nras_ex_3
# WT          404
# FAIL         11
# M (Q61L)      3
# M (Q61K)      2
# M (Q61R)      2
# Name: count, dtype: int64
#
# braf_mutant_status
# WT                        376
# M (V600E)                  37
# M (V600E) - LOW LEVEL       5
# M (V600E)                   1
# M (D584N) - LOW LEVEL       1
# M (S605G) - LOW LEVEL       1
# M (R603Q) - LOW LEVEL)      1
# Name: count, dtype: int64

# %%
#Dealing with binary values in kras_ex_2, kras_ex_3, nras_ex_2,braf_mutant_status, and kras_codon_117
for attribute in ["kras_ex_2","kras_ex_3","nras_ex_2","braf_mutant_status"]:
    df[attribute] = df[attribute].map({'WT': 0, 'M': 1}) #Mapping WT as 0 and M as 1
    print(df[attribute].value_counts())
    print()
df["kras_codon_117"] = df["kras_codon_117"].map({'WT': 0, 'FAIL': 1})
# Out:
# kras_ex_2
# 0    288
# 1    134
# Name: count, dtype: int64
#
# kras_ex_3
# 0    411
# 1     11
# Name: count, dtype: int64
#
# nras_ex_2
# 0    413
# 1      9
# Name: count, dtype: int64
#
# braf_mutant_status
# 0    376
# 1     46
# Name: count, dtype: int64

# %%
#Cleaning the stage and stage_subgroup
print(df[df["stage"].isna() == True].to_string()) #Examaning the row where "stage" is empty
df=df[df["stage"].isna() == False] #Removing the row since too many columns are empty

#Performing ordinal encoding on the attributes
stage_mapping = {'1': 1, '2': 2, '3': 3, '3C': 4, '4': 5}
df['stage'] = df['stage'].map(stage_mapping)

stage_subgroup_map = {
    '1': 1,
    '2A': 2,
    '2B': 3,
    '3A': 4,
    '3B': 5,
    '3C': 6,
    '4': 7
}
df['stage_subgroup'] = df['stage_subgroup'].map(stage_subgroup_map)
# Out:
#      died_within_5_years  age_at_diagnosis  male site_of_tumour site_of_tumour_grouping  kras_ex_2  kras_ex_3  kras_codon_117  nras_ex_2 nras_ex_3  braf_mutant_status  mmr_ihc  mmr_loss_binary stage stage_subgroup   pT   pN differentiation peri_surface_involved em_lvi
# 321                    1                59     1         others                  caecum          0          0               0          1        WT                   0  NO LOSS                0   NaN            NaN  NaN  NaN             NaN                   NaN    NaN

# %%
#Cleaning the pT and pN attribute
attributes = ["pT","pN"]
for attribute in attributes:
    counts = df[attribute].value_counts()
    print (counts) #Print value counts
    other_values = list(counts[counts<=4].index) #Other values which their counts are <=4 (too rare)
    df[attribute] = df[attribute].replace(other_values,"others")
    print()
# Out:
# pT
# pT3     209
# pT2      69
# pT4b     68
# pT4      30
# ypT3     17
# pT1      12
# pT4a     10
# ypT2      3
# ypT1      1
# Pt3       1
# pT        1
# Name: count, dtype: int64
#
# pN
# N0      211
# N1      118
# N2       72
# ypN2      4
# pN1       4
# pN0       4
# pN2       4
# NX        1
# ypN0      1
# Nx        1
# ypN1      1
# Name: count, dtype: int64

# %%
#Cleaning the differentiation attribute
print("Missing values: ", df["differentiation"].isna().sum())
print(df[df["differentiation"].isna()==True].to_string()) #Inspecting the missing value row
df = df[df["differentiation"].isna()==False] #Dropping the row since too many missing values

print(df["differentiation"].unique()) #Look at the unique values

def poor_mod_well(x):
    x=x.lower() #Convert all to lower case
    if "poor" in x and "mod" not in x:
        return 1 #poor
    elif "poor" in x and "mod" in x:
        return 2 #poor_mod
    elif "mod" in x and "well" not in x:
        return 3 #mod
    elif "mod" in x and "well" in x:
        return 4 #mod_well
    else:
        return 5 #well

df["differentiation"]=df["differentiation"].apply(poor_mod_well)

#Visualizations of distribution
sns.histplot(df["differentiation"])
# Out:
# Missing values:  1
#    died_within_5_years  age_at_diagnosis  male site_of_tumour site_of_tumour_grouping  kras_ex_2  kras_ex_3  kras_codon_117  nras_ex_2 nras_ex_3  braf_mutant_status  mmr_ihc  mmr_loss_binary  stage  stage_subgroup   pT      pN differentiation peri_surface_involved em_lvi
# 0                    1                91     0   lower rectum                  rectum          1          0               0          0        WT                   0  NO LOSS                0      1               1  pT2  others             NaN                   NaN    NaN
# ['Mod' 'Poor (areas of moderate)' 'Well (focally mod)'
#  'Mod (focally poor)' 'Mod (foci of poor at invasive front)' 'Poor' 'Well'
#  'Mod (predominantly)' 'Poor (some mod regions with medullary features)'
#  'Well to Mod (mucinous component)'
#  'Mod (leading edge poor with tumour budding)' 'Mod to Poor'
#  'Mod (areas of poor)'
#  'Mod (small focus of mucinous differentiation and small foci of poor)'
#  'Mod (some foci of poor)' 'Mod (some areas of poor)'
#  'Mod (small areas of poorly differentiated)'
#  'Mod (focal poor at invasive front)' 'Mod (foci of poor)'
#  'Mod (areas of mucinous, areas of poor)'
#  'Mod (mucinous areas and occasional signet)'
#  'Poor (focal signet ring cell morph)'
#  'Mod (some mucinous differentiation)' 'Mod-Poor'
#  'Mod (areas of poor differentiation, focal mucinous differentiation)'
#  'Mod (areas of focal poor)' 'Mod to Poor (sig areas of poor)'
#  'Mod (papillary architecture and mucinous differentiation)'
#  'Focally poor but overall mod']
# <Axes: xlabel='differentiation', ylabel='Count'>

# %%
#Cleaning the peri_surface_involved attribute
print(df["peri_surface_involved"].value_counts())
df["peri_surface_involved"]=df["peri_surface_involved"].replace('Not directly visualised but presumed yes',"Y") 

def unknown(x):
    if x != "N" and x!="Y":
        return np.nan
    else:
        return x

df["peri_surface_involved"] = df["peri_surface_involved"].apply(unknown)

df["peri_surface_involved"]=df["peri_surface_involved"].fillna(df["peri_surface_involved"].mode()[0]) #Fill missing values with mode since categorical value
df["peri_surface_involved"]=df["peri_surface_involved"].map({'Y': 1, 'N': 0})

#Visualizations of distribution
sns.histplot(df["peri_surface_involved"])
# Out:
# peri_surface_involved
# N                                           293
# Y                                            93
# Not identified                               13
# -                                            10
# ??                                            3
# N (N/A)                                       1
# Absent                                        1
# Not directly visualised but presumed yes      1
# N?                                            1
# Name: count, dtype: int64
# <Axes: xlabel='peri_surface_involved', ylabel='Count'>

# %%
#Cleaning em_lvi attribute

#Checking missing values
print("Missing values: ",df["em_lvi"].isna().sum())

print(df["em_lvi"].value_counts()) #Inspecting value counts
df["em_lvi"]=df["em_lvi"].replace("Probable","Y")

df["em_lvi"]=df["em_lvi"].apply(unknown)

df["em_lvi"]=df["em_lvi"].fillna(df["em_lvi"].mode()[0]) #Fill missing values with mode since categorical value
df["em_lvi"]=df["em_lvi"].map({'Y': 1, 'N': 0})

#Visualizations of distribution
sns.histplot(df["em_lvi"])
# Out:
# Missing values:  1
# em_lvi
# N                 225
# Y                 171
# Not identified     18
# Probable            2
# -                   2
# Not present         1
# Name: count, dtype: int64
# <Axes: xlabel='em_lvi', ylabel='Count'>

# %%
#Perform one-hot encoding on catergorical attributes
df = pd.get_dummies(df,columns=["site_of_tumour","site_of_tumour_grouping","nras_ex_3","mmr_ihc","pT","pN"],drop_first=True,dtype=int)

# %%
#Scaling the ordinal attributes in the dataset
from sklearn.preprocessing import MinMaxScaler #MinMaxScaler since other values are 0 or 1 (binary value) so scaled values should be between 0-1
ordinal_attributes = ["age_at_diagnosis","stage","stage_subgroup","differentiation"]
scaler = MinMaxScaler()
df[ordinal_attributes] = scaler.fit_transform(df[ordinal_attributes])

# %%
#Splitting the dataset into test, train & val
from sklearn.model_selection import train_test_split
X=df.drop(labels="died_within_5_years",axis=1)
y=df["died_within_5_years"]
#Testing is 15% of original
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42, stratify=y) #Stratify to preserve class ratios

#Val is 15% of original, so of 85%, it is 15% of 85%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=15/85, random_state=42, stratify=y_train)

print("Train:", X_train.shape)
print("Val:", X_val.shape)
print("Test:", X_test.shape)
# Out:
# Train: (293, 48)
# Val: (64, 48)
# Test: (63, 48)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"  # Force CPU
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam

# %%
#Defining the architecture
model = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(32, activation="relu"),
    Dense(1, activation="sigmoid")
])

# %%
#Compiling the model
model.compile(
    optimizer=Adam(learning_rate=1e-3),
    loss="binary_crossentropy",
    metrics=["accuracy", tf.keras.metrics.AUC(name="auc")]
)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 32)             │         1,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,601 (6.25 KB)
#  Trainable params: 1,601 (6.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Training the model
history = model.fit(
    X_train,y_train,
    validation_data = (X_val,y_val),
    epochs = 100,
    batch_size = 32,
    verbose=1
)
# Out:
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4096 - auc: 0.3278 - loss: 0.7358 - val_accuracy: 0.5000 - val_auc: 0.3276 - val_loss: 0.7204
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4983 - auc: 0.3823 - loss: 0.6995 - val_accuracy: 0.5625 - val_auc: 0.3990 - val_loss: 0.6947
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5973 - auc: 0.4652 - loss: 0.6747 - val_accuracy: 0.6094 - val_auc: 0.4755 - val_loss: 0.6745
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6246 - auc: 0.5538 - loss: 0.6557 - val_accuracy: 0.6250 - val_auc: 0.5391 - val_loss: 0.6586
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6348 - auc: 0.6168 - loss: 0.6411 - val_accuracy: 0.6406 - val_auc: 0.6219 - val_loss: 0.6419
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6587 - auc: 0.6599 - loss: 0.6272 - val_accuracy: 0.6406 - val_auc: 0.6615 - val_loss: 0.6279
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6826 - auc: 0.6925 - loss: 0.6131 - val_accuracy: 0.6875 - val_auc: 0.6969 - val_loss: 0.6144
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7133 - auc: 0.7116 - loss: 0.6032 - val_accuracy: 0.7031 - val_auc: 0.7427 - val_loss: 0.5995
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7304 - auc: 0.7294 - loss: 0.5927 - val_accuracy: 0.7344 - val_auc: 0.7500 - val_loss: 0.5882
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7372 - auc: 0.7389 - loss: 0.5816 - val_accuracy: 0.7344 - val_auc: 0.7578 - val_loss: 0.5791
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7406 - auc: 0.7459 - loss: 0.5735 - val_accuracy: 0.7500 - val_auc: 0.7615 - val_loss: 0.5730
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7440 - auc: 0.7559 - loss: 0.5668 - val_accuracy: 0.7500 - val_auc: 0.7682 - val_loss: 0.5671
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7474 - auc: 0.7657 - loss: 0.5600 - val_accuracy: 0.7500 - val_auc: 0.7698 - val_loss: 0.5616
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7474 - auc: 0.7684 - loss: 0.5544 - val_accuracy: 0.7500 - val_auc: 0.7729 - val_loss: 0.5551
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7474 - auc: 0.7728 - loss: 0.5491 - val_accuracy: 0.7500 - val_auc: 0.7797 - val_loss: 0.5502
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7474 - auc: 0.7769 - loss: 0.5448 - val_accuracy: 0.7500 - val_auc: 0.7797 - val_loss: 0.5447
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7474 - auc: 0.7824 - loss: 0.5400 - val_accuracy: 0.7344 - val_auc: 0.7812 - val_loss: 0.5410
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7509 - auc: 0.7818 - loss: 0.5367 - val_accuracy: 0.7344 - val_auc: 0.7797 - val_loss: 0.5399
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7509 - auc: 0.7894 - loss: 0.5326 - val_accuracy: 0.7344 - val_auc: 0.7828 - val_loss: 0.5372
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7577 - auc: 0.7939 - loss: 0.5290 - val_accuracy: 0.7344 - val_auc: 0.7797 - val_loss: 0.5355
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7543 - auc: 0.7979 - loss: 0.5257 - val_accuracy: 0.7500 - val_auc: 0.7781 - val_loss: 0.5334
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7577 - auc: 0.7994 - loss: 0.5221 - val_accuracy: 0.7500 - val_auc: 0.7760 - val_loss: 0.5331
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7543 - auc: 0.8020 - loss: 0.5187 - val_accuracy: 0.7656 - val_auc: 0.7781 - val_loss: 0.5299
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7474 - auc: 0.8060 - loss: 0.5152 - val_accuracy: 0.7500 - val_auc: 0.7771 - val_loss: 0.5305
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7543 - auc: 0.8097 - loss: 0.5131 - val_accuracy: 0.7344 - val_auc: 0.7771 - val_loss: 0.5298
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7577 - auc: 0.8125 - loss: 0.5113 - val_accuracy: 0.7344 - val_auc: 0.7766 - val_loss: 0.5293
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7543 - auc: 0.8167 - loss: 0.5075 - val_accuracy: 0.7500 - val_auc: 0.7729 - val_loss: 0.5324
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7611 - auc: 0.8164 - loss: 0.5081 - val_accuracy: 0.7656 - val_auc: 0.7708 - val_loss: 0.5346
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7543 - auc: 0.8185 - loss: 0.5052 - val_accuracy: 0.7500 - val_auc: 0.7776 - val_loss: 0.5310
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7679 - auc: 0.8217 - loss: 0.5011 - val_accuracy: 0.7500 - val_auc: 0.7812 - val_loss: 0.5278
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7713 - auc: 0.8244 - loss: 0.4986 - val_accuracy: 0.7500 - val_auc: 0.7812 - val_loss: 0.5272
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7645 - auc: 0.8242 - loss: 0.4968 - val_accuracy: 0.7656 - val_auc: 0.7823 - val_loss: 0.5263
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7679 - auc: 0.8261 - loss: 0.4947 - val_accuracy: 0.7656 - val_auc: 0.7812 - val_loss: 0.5264
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7679 - auc: 0.8276 - loss: 0.4924 - val_accuracy: 0.7656 - val_auc: 0.7797 - val_loss: 0.5265
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7645 - auc: 0.8282 - loss: 0.4910 - val_accuracy: 0.7656 - val_auc: 0.7797 - val_loss: 0.5259
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7679 - auc: 0.8304 - loss: 0.4888 - val_accuracy: 0.7656 - val_auc: 0.7849 - val_loss: 0.5254
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7713 - auc: 0.8328 - loss: 0.4866 - val_accuracy: 0.7656 - val_auc: 0.7823 - val_loss: 0.5266
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7747 - auc: 0.8330 - loss: 0.4861 - val_accuracy: 0.7656 - val_auc: 0.7792 - val_loss: 0.5300
# Epoch 39/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7713 - auc: 0.8353 - loss: 0.4848 - val_accuracy: 0.7656 - val_auc: 0.7823 - val_loss: 0.5283
# Epoch 40/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7747 - auc: 0.8391 - loss: 0.4808 - val_accuracy: 0.7656 - val_auc: 0.7828 - val_loss: 0.5288
# Epoch 41/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7782 - auc: 0.8404 - loss: 0.4789 - val_accuracy: 0.7656 - val_auc: 0.7807 - val_loss: 0.5301
# Epoch 42/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7782 - auc: 0.8412 - loss: 0.4783 - val_accuracy: 0.7656 - val_auc: 0.7797 - val_loss: 0.5326
# Epoch 43/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7713 - auc: 0.8442 - loss: 0.4751 - val_accuracy: 0.7500 - val_auc: 0.7786 - val_loss: 0.5330
# Epoch 44/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7645 - auc: 0.8447 - loss: 0.4744 - val_accuracy: 0.7656 - val_auc: 0.7781 - val_loss: 0.5352
# Epoch 45/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7645 - auc: 0.8469 - loss: 0.4721 - val_accuracy: 0.7656 - val_auc: 0.7786 - val_loss: 0.5364
# Epoch 46/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7645 - auc: 0.8476 - loss: 0.4712 - val_accuracy: 0.7656 - val_auc: 0.7771 - val_loss: 0.5396
# Epoch 47/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7713 - auc: 0.8501 - loss: 0.4682 - val_accuracy: 0.7500 - val_auc: 0.7750 - val_loss: 0.5440
# Epoch 48/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7816 - auc: 0.8482 - loss: 0.4685 - val_accuracy: 0.7500 - val_auc: 0.7729 - val_loss: 0.5470
# Epoch 49/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7816 - auc: 0.8509 - loss: 0.4654 - val_accuracy: 0.7500 - val_auc: 0.7740 - val_loss: 0.5465
# Epoch 50/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7713 - auc: 0.8497 - loss: 0.4648 - val_accuracy: 0.7656 - val_auc: 0.7750 - val_loss: 0.5457
# Epoch 51/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7713 - auc: 0.8498 - loss: 0.4662 - val_accuracy: 0.7812 - val_auc: 0.7792 - val_loss: 0.5464
# Epoch 52/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7782 - auc: 0.8502 - loss: 0.4635 - val_accuracy: 0.7656 - val_auc: 0.7745 - val_loss: 0.5461
# Epoch 53/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7782 - auc: 0.8530 - loss: 0.4596 - val_accuracy: 0.7656 - val_auc: 0.7687 - val_loss: 0.5493
# Epoch 54/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7782 - auc: 0.8544 - loss: 0.4583 - val_accuracy: 0.7656 - val_auc: 0.7734 - val_loss: 0.5486
# Epoch 55/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7782 - auc: 0.8552 - loss: 0.4566 - val_accuracy: 0.7500 - val_auc: 0.7729 - val_loss: 0.5504
# Epoch 56/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7782 - auc: 0.8572 - loss: 0.4551 - val_accuracy: 0.7500 - val_auc: 0.7740 - val_loss: 0.5531
# Epoch 57/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7850 - auc: 0.8563 - loss: 0.4541 - val_accuracy: 0.7500 - val_auc: 0.7729 - val_loss: 0.5553
# Epoch 58/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7850 - auc: 0.8578 - loss: 0.4525 - val_accuracy: 0.7500 - val_auc: 0.7724 - val_loss: 0.5581
# Epoch 59/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7850 - auc: 0.8588 - loss: 0.4514 - val_accuracy: 0.7656 - val_auc: 0.7708 - val_loss: 0.5591
# Epoch 60/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7816 - auc: 0.8609 - loss: 0.4497 - val_accuracy: 0.7500 - val_auc: 0.7708 - val_loss: 0.5600
# Epoch 61/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7884 - auc: 0.8619 - loss: 0.4481 - val_accuracy: 0.7656 - val_auc: 0.7672 - val_loss: 0.5638
# Epoch 62/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7884 - auc: 0.8624 - loss: 0.4471 - val_accuracy: 0.7656 - val_auc: 0.7672 - val_loss: 0.5661
# Epoch 63/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7850 - auc: 0.8645 - loss: 0.4467 - val_accuracy: 0.7656 - val_auc: 0.7641 - val_loss: 0.5694
# Epoch 64/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7918 - auc: 0.8670 - loss: 0.4447 - val_accuracy: 0.7656 - val_auc: 0.7630 - val_loss: 0.5704
# Epoch 65/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7884 - auc: 0.8676 - loss: 0.4433 - val_accuracy: 0.7656 - val_auc: 0.7630 - val_loss: 0.5723
# Epoch 66/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7850 - auc: 0.8688 - loss: 0.4423 - val_accuracy: 0.7656 - val_auc: 0.7625 - val_loss: 0.5726
# Epoch 67/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7884 - auc: 0.8706 - loss: 0.4400 - val_accuracy: 0.7656 - val_auc: 0.7630 - val_loss: 0.5731
# Epoch 68/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7884 - auc: 0.8719 - loss: 0.4384 - val_accuracy: 0.7812 - val_auc: 0.7625 - val_loss: 0.5738
# Epoch 69/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7918 - auc: 0.8746 - loss: 0.4358 - val_accuracy: 0.7969 - val_auc: 0.7625 - val_loss: 0.5745
# Epoch 70/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7850 - auc: 0.8744 - loss: 0.4355 - val_accuracy: 0.7969 - val_auc: 0.7625 - val_loss: 0.5768
# Epoch 71/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7884 - auc: 0.8751 - loss: 0.4341 - val_accuracy: 0.7812 - val_auc: 0.7620 - val_loss: 0.5771
# Epoch 72/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7884 - auc: 0.8762 - loss: 0.4319 - val_accuracy: 0.7812 - val_auc: 0.7625 - val_loss: 0.5788
# Epoch 73/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7952 - auc: 0.8777 - loss: 0.4305 - val_accuracy: 0.7812 - val_auc: 0.7604 - val_loss: 0.5816
# Epoch 74/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7884 - auc: 0.8785 - loss: 0.4300 - val_accuracy: 0.7812 - val_auc: 0.7583 - val_loss: 0.5832
# Epoch 75/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7884 - auc: 0.8809 - loss: 0.4273 - val_accuracy: 0.7812 - val_auc: 0.7625 - val_loss: 0.5815
# Epoch 76/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7918 - auc: 0.8815 - loss: 0.4267 - val_accuracy: 0.7969 - val_auc: 0.7677 - val_loss: 0.5812
# Epoch 77/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7884 - auc: 0.8813 - loss: 0.4265 - val_accuracy: 0.7969 - val_auc: 0.7667 - val_loss: 0.5823
# Epoch 78/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7884 - auc: 0.8846 - loss: 0.4230 - val_accuracy: 0.7500 - val_auc: 0.7630 - val_loss: 0.5863
# Epoch 79/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7986 - auc: 0.8825 - loss: 0.4257 - val_accuracy: 0.7500 - val_auc: 0.7620 - val_loss: 0.5899
# Epoch 80/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7884 - auc: 0.8844 - loss: 0.4215 - val_accuracy: 0.7969 - val_auc: 0.7630 - val_loss: 0.5898
# Epoch 81/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8020 - auc: 0.8865 - loss: 0.4204 - val_accuracy: 0.7656 - val_auc: 0.7604 - val_loss: 0.5938
# Epoch 82/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7986 - auc: 0.8877 - loss: 0.4189 - val_accuracy: 0.7656 - val_auc: 0.7620 - val_loss: 0.5947
# Epoch 83/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8055 - auc: 0.8896 - loss: 0.4167 - val_accuracy: 0.7500 - val_auc: 0.7635 - val_loss: 0.5952
# Epoch 84/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8157 - auc: 0.8890 - loss: 0.4174 - val_accuracy: 0.7969 - val_auc: 0.7641 - val_loss: 0.5969
# Epoch 85/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8157 - auc: 0.8915 - loss: 0.4156 - val_accuracy: 0.7656 - val_auc: 0.7604 - val_loss: 0.6005
# Epoch 86/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8055 - auc: 0.8932 - loss: 0.4133 - val_accuracy: 0.7656 - val_auc: 0.7583 - val_loss: 0.6010
# Epoch 87/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8020 - auc: 0.8945 - loss: 0.4116 - val_accuracy: 0.7656 - val_auc: 0.7583 - val_loss: 0.6023
# Epoch 88/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8020 - auc: 0.8932 - loss: 0.4117 - val_accuracy: 0.7656 - val_auc: 0.7536 - val_loss: 0.6044
# Epoch 89/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8055 - auc: 0.8951 - loss: 0.4103 - val_accuracy: 0.7812 - val_auc: 0.7531 - val_loss: 0.6069
# Epoch 90/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8089 - auc: 0.8956 - loss: 0.4077 - val_accuracy: 0.7656 - val_auc: 0.7589 - val_loss: 0.6047
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8157 - auc: 0.8978 - loss: 0.4080 - val_accuracy: 0.7656 - val_auc: 0.7599 - val_loss: 0.6084
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8225 - auc: 0.8994 - loss: 0.4062 - val_accuracy: 0.7500 - val_auc: 0.7552 - val_loss: 0.6129
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8089 - auc: 0.8990 - loss: 0.4047 - val_accuracy: 0.7656 - val_auc: 0.7547 - val_loss: 0.6127
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8089 - auc: 0.9002 - loss: 0.4039 - val_accuracy: 0.7812 - val_auc: 0.7547 - val_loss: 0.6121
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8123 - auc: 0.8995 - loss: 0.4022 - val_accuracy: 0.7656 - val_auc: 0.7568 - val_loss: 0.6126
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8157 - auc: 0.9013 - loss: 0.4001 - val_accuracy: 0.7500 - val_auc: 0.7573 - val_loss: 0.6122
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8259 - auc: 0.9022 - loss: 0.4002 - val_accuracy: 0.7500 - val_auc: 0.7615 - val_loss: 0.6141
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8259 - auc: 0.9023 - loss: 0.3985 - val_accuracy: 0.7656 - val_auc: 0.7599 - val_loss: 0.6157
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8225 - auc: 0.9037 - loss: 0.3963 - val_accuracy: 0.7812 - val_auc: 0.7599 - val_loss: 0.6173
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8191 - auc: 0.9038 - loss: 0.3963 - val_accuracy: 0.7656 - val_auc: 0.7620 - val_loss: 0.6183

# %%
pd.DataFrame(history.history)
# Out:
#     accuracy       auc      loss  val_accuracy   val_auc  val_loss
# 0   0.409556  0.327807  0.735789      0.500000  0.327604  0.720385
# 1   0.498294  0.382280  0.699480      0.562500  0.398958  0.694685
# 2   0.597270  0.465173  0.674655      0.609375  0.475521  0.674520
# 3   0.624573  0.553824  0.655709      0.625000  0.539062  0.658570
# 4   0.634812  0.616848  0.641136      0.640625  0.621875  0.641948
# ..       ...       ...       ...           ...       ...       ...
# 95  0.815700  0.901326  0.400102      0.750000  0.757292  0.612207
# 96  0.825939  0.902224  0.400230      0.750000  0.761458  0.614062
# 97  0.825939  0.902299  0.398523      0.765625  0.759896  0.615706
# 98  0.822526  0.903720  0.396328      0.781250  0.759896  0.617285
# 99  0.819113  0.903769  0.396314      0.765625  0.761979  0.618328
#
# [100 rows x 6 columns]

# %%
#Seeing how the metrics change for each epoch
metrics = ["accuracy","auc","loss"]
for metric in metrics:
    plt.plot(history.history[metric], label=f"train {metric}")
    plt.plot(history.history[f"val_{metric}"], label=f"val {metric}")
    plt.legend()
    plt.xlabel("Epoch")
    plt.ylabel(metric)
    plt.show()
